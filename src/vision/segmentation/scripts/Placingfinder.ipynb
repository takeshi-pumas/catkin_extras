# %%
from utils import *
import matplotlib.pyplot as plt
# Out:
# /home/roboworks/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
points_msg=rospy.wait_for_message("/hsrb/head_rgbd_sensor/depth_registered/rectified_points",PointCloud2,timeout=5)

# %%
points_data = ros_numpy.numpify(points_msg)    
image_data = points_data['rgb'].view((np.uint8, 4))[..., [2, 1, 0]]   
image=cv2.cvtColor(image_data, cv2.COLOR_BGR2RGB)
image = points_data['rgb'].view((np.uint8, 4))[..., [2, 1, 0]]
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb_image)

# %%
try:
        trans = tfBuffer.lookup_transform('map', 'head_rgbd_sensor_link', rospy.Time())
                    
        trans,rot=read_tf(trans)
        #print ("############head",trans,rot)
except (tf2_ros.LookupException, tf2_ros.ConnectivityException, tf2_ros.ExtrapolationException):
        print ( 'No head TF FOUND')
t= write_tf(trans,rot)
cloud_out = do_transform_cloud(points_msg, t)
# Out:
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1160.793000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1160.793000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp

# %%
np_corrected=ros_numpy.numpify(cloud_out)
corrected=np_corrected.reshape(points_data.shape)

# %%
plt.imshow(points_data['z'])

# %%
plt.imshow(corrected['z'])

# %%
img_z=corrected['z']
plt.imshow(img_z)
# Out:
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1162.438000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1162.438000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp

# %%
zs_no_nans=corrected['z'][~np.isnan(corrected['z'])]
counts, bins =(np.histogram(zs_no_nans, bins=100))
inds=np.where(counts>10000)
planes_heights=bins[np.add(inds, 1)].flatten()
print (f'Number of planes found {len(inds[0])} at z=[{bins[ np.add(inds, 1)]}]#############3')
print (f'Plane heights detected {planes_heights} maximum  z=[{planes_heights.max()}]#############3')

fig, ax = plt.subplots()
ax.bar(bins[:-1], counts, width=np.diff(bins), edgecolor="black", align="edge")

plt.show()
# Out:
# Number of planes found 4 at z=[[[0.01505015 0.06610453 0.45411786 0.8217094 ]]]#############3
# Plane heights detected [0.01505015 0.06610453 0.45411786 0.8217094 ] maximum  z=[0.821709394454956]#############3

# %%
plane_height=planes_heights.max()
low_plane = (corrected['z'] > (plane_height-0.02)) #plane height
high_plane = (corrected['z'] < (plane_height+0.02))#plane height + obj height
z_lims=np.logical_and(low_plane, high_plane)
# Out:
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1165.376000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1165.376000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1167.741000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1167.741000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp

# %%
result_indices = np.where(z_lims)#np.logical_and(z_lims, x_lims))
x=np.asarray((corrected['x'][result_indices].min(),corrected['x'][result_indices].max())).reshape(-1, 1)
y=np.asarray((corrected['y'][result_indices].min(),corrected['y'][result_indices].max())).reshape(-1, 1)

region=np.append(x,y,axis=1)
print(f'region{region}')


rospack = rospkg.RosPack()        
file_path = rospack.get_path('config_files') 
np.save(file_path+'/regions/shelves_region.npy',region)
# Out:
# region[[3.482517   0.64121866]
#  [4.0643725  2.1010995 ]]
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1176.640000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1176.640000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1178.446000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1178.446000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1179.045000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1179.045000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1179.611000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1179.611000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1179.925000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1179.925000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1180.532000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1180.532000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1180.926000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1180.926000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1181.099000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1181.099000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1181.173000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1181.173000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp

# %%
#np.save('/home/roboworks/catkin_extras/src/navigation_pumas/config_files/regions/pickup_region.npy',area)
#np.save(('/home/roboworks/catkin_extras/src/navigation_pumas/config_files/regions/pickup_region.npy'),area)
# Out:
# '/home/roboworks/catkin_extras/src/navigation_pumas/config_files/regions/pickup_region.npy'
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 367.895000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 367.895000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 367.961000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 367.961000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 375.885000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 375.885000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 377.951000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 377.951000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 378.019000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 378.019000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 378.088000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 378.088000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 378.715000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 378.715000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 378.856000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 378.856000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 388.772000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 388.772000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 398.024000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 398.024000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 401.898000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 401.898000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 411.346000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 411.346000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 416.670000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 416.670000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 418.387000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 418.387000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 420.889000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 420.889000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 422.841000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 422.841000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 423.085000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 423.085000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 425.747000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 425.747000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 426.883000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 426.883000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 428.316000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 428.316000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 429.710000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 429.710000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 434.940000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 434.940000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 437.706000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 437.706000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 442.534000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 442.534000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 443.674000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 443.674000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 443.829000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 443.829000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 445.665000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 445.665000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 447.458000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 447.458000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 451.339000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 451.339000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 457.430000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 457.430000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 458.191000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 458.191000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 463.986000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 463.986000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 469.854000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 469.854000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 471.108000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 471.108000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 471.218000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 471.218000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 471.365000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 471.365000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 476.529000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 476.529000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 477.997000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 477.997000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 479.928000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 479.928000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 480.251000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 480.251000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 481.949000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 481.949000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 491.856000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 491.856000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 493.881000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 493.881000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 495.149000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 495.149000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 495.649000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 495.649000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 495.951000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 495.951000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 499.961000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 499.961000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 501.339000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 501.339000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 510.665000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 510.665000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 511.482000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 511.482000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 511.576000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 511.576000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 516.912000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 516.912000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 522.655000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 522.655000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 524.059000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 524.059000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 532.129000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 532.129000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 537.787000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 537.787000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 539.168000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 539.168000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 540.967000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 540.967000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 552.921000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 552.921000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 555.527000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 555.527000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 558.848000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 558.848000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 559.448000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 559.448000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 562.528000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 562.528000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 566.378000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 566.378000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 569.079000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 569.079000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 569.138000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 569.138000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 574.933000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 574.933000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 575.733000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 575.733000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 576.758000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 576.758000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 577.673000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 577.673000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 581.433000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 581.433000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 605.744000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 605.744000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 612.231000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 612.231000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 613.399000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 613.399000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 614.006000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 614.006000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 614.395000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 614.395000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 619.293000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 619.293000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 625.588000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 625.588000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 628.457000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 628.457000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 629.867000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 629.867000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 630.251000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 630.251000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 630.427000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 630.427000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 630.849000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 630.849000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 632.280000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 632.280000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 634.996000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 634.996000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 635.638000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 635.638000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 640.131000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 640.131000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 642.956000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 642.956000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 643.738000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 643.738000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 644.351000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 644.351000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 644.456000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 644.456000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 645.974000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 645.974000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 646.828000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 646.828000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 647.041000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 647.041000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 647.762000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 647.762000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 648.006000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 648.006000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 648.254000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 648.254000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 652.780000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 652.780000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 652.864000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 652.864000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 653.886000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 653.886000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 654.412000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 654.412000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 654.548000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 654.548000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 655.006000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 655.006000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 655.465000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 655.465000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 659.511000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 659.511000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 660.554000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 660.554000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 661.276000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 661.276000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 662.010000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 662.010000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 673.144000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 673.144000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 674.942000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 674.942000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 675.010000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 675.010000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 676.211000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 676.211000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 676.777000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 676.777000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp

# %%
### MODIFICATION FOR STORING GRECIES, FINDING PLACING PLANE
orig_image= rgb_image.copy()
mask= np.zeros(corrected['z'].shape)#mask

###TOP PLANE ################################
#low_plane = (corrected['z'] > 0.64) #plane height
#high_plane = (corrected['z'] < 0.68)#plane height + obj height
###################3
###MID PLANE ################################
#low_plane = (corrected['z'] > 0.36) #plane height
#high_plane = (corrected['z'] < 0.4)#plane height + obj height
###################3
###BTM PLANE ################################
#low_plane = (corrected['z'] > 0.04) #plane height
#high_plane = (corrected['z'] < 0.1)#plane height + obj height
###################3



#x coords placing plane limit
orig_image= rgb_image.copy()
mask= np.zeros(corrected['z'].shape)#mask
z_lims=np.logical_and(low_plane, high_plane)
result_indices = np.where(z_lims)#np.logical_and(z_lims, x_lims))
mask[result_indices]=200
_, binary_image = cv2.threshold(mask, 20, 255, cv2.THRESH_BINARY)
eroded_image=cv2.erode(binary_image,kernel = np.ones((40, 40), np.uint8))

print ('quick estimation',np.nanmean(corrected['x'][np.where(eroded_image==255)]),np.nanmean(corrected['y'][np.where(eroded_image==255)]),np.nanmean(corrected['z'][np.where(eroded_image==255)]))
contours, hierarchy = cv2.findContours(eroded_image.astype(np.uint8) ,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
cc=[]
for contour in contours:
    M = cv2.moments(contour)
    area = cv2.contourArea(contour)
    if area > 200:
        print ('yo')
        
    # calculate x,y coordinate of center
        cX = int(M["m10"] / M["m00"])
        cY = int(M["m01"] / M["m00"])
        cc.append((cX,cY))
        eroded_image=cv2.circle(binary_image, (cX, cY), 5, (200, 200, 200), -1)
for (cX,cY) in cc:
    x,y = cX,cY
    
    pose=np.asarray((np.mean(corrected['x'][y-15:y+15,x-15:x+15]), np.mean(corrected['y'][y-15:y+15,x-15:x+15]),np.mean(corrected['z'][y-15:y+15,x-15:x+15]) + 0.05))    
    print('estimation', pose)

    
    


plt.imshow(eroded_image)
# Out:
# quick estimation 5.2556114 2.7465203 0.39988232
# yo
# yo
# estimation [5.34326935 2.75412321 0.449894  ]
# estimation [4.73000669 2.74660587 0.44980334]

# %%
eroded_image=cv2.erode(binary_image,kernel = np.ones((40, 40), np.uint8))
plt.imshow(eroded_image)

# %%
np.nanmean(corrected['x'][np.where(eroded_image==255)]),np.nanmean(corrected['y'][np.where(eroded_image==255)]),np.nanmean(corrected['z'][np.where(eroded_image==255)])
# Out:
# (8.138051, 6.101691, 0.66955155)

# %%
#eroded_image=cv2.erode(binary_image,kernel = np.ones((25, 25), np.uint8))
contours, hierarchy = cv2.findContours(eroded_image.astype(np.uint8) ,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
cc=[]
for contour in contours:
    M = cv2.moments(contour)
    area = cv2.contourArea(contour)
    if area > 200:
        print ('yo')
        
    # calculate x,y coordinate of center
        cX = int(M["m10"] / M["m00"])
        cY = int(M["m01"] / M["m00"])
        cc.append((cX,cY))
        eroded_image=cv2.circle(binary_image, (cX, cY), 5, (200, 200, 200), -1)
    
    #boundRect = cv2.boundingRect(contour)
    
plt.imshow(eroded_image)
# Out:
# yo
# yo

# %%
cc
# Out:
# [(52, 321), (270, 291)]

# %%
for (cX,cY) in cc:
    x,y = cX,cY
    print (np.mean(binary_image[y-35:y+35,x-35:x+35]))
    pose=np.asarray((np.mean(corrected['x'][y-15:y+15,x-15:x+15]), np.mean(corrected['y'][y-15:y+15,x-15:x+15]),np.mean(corrected['z'][y-15:y+15,x-15:x+15])))
    binary_image[y-15:y+15,x-15:x+15]=100
    
plt.imshow(binary_image)
pose
# Out:
# 228.0704081632653
# 243.31836734693877
# array([8.163747  , 6.105586  , 0.66955674], dtype=float32)
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1248.024000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1248.024000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1280.153000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1280.153000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp

# %%
pose=np.asarray((np.mean(corrected['x'][y-15:y+15,x-15:x+15]), np.mean(corrected['y'][y-15:y+15,x-15:x+15]),np.mean(corrected['z'][y-15:y+15,x-15:x+15]) + 0.05))

# %%
tf

# %%
pose

# %%
xs,ys=np.where(binary_image==255 )[0] ,np.where(binary_image==255 )[1]
for x,y  in zip(xs,ys):
    cha=np.mean(binary_image[y-35:y+35,x-35:x+35])
    if cha !=0:print(cha)
    if cha >8:  #AREA
        print(cha,'cha')
            
        binary_image[y-35:y+35,x-35:x+35]=100
plt.imshow(binary_image)

# %%
orig_image= rgb_image.copy()
mask= np.zeros(corrected['z'].shape)#mask
#low_plane = (corrected['z'] > 0.07) #plane height
#high_plane = (corrected['z'] < 0.12)#plane height + obj height
low_plane = (corrected['z'] > 0.64) #plane height
high_plane = (corrected['z'] < 0.68)#plane height + obj height
result_indices = np.where(np.logical_and(low_plane, high_plane))
mask[result_indices]=200
_, binary_image = cv2.threshold(mask, 20, 255, cv2.THRESH_BINARY)

###############FOR DEBUG IMAGE
cv2_image = cv2.cvtColor(binary_image.astype(np.uint8), cv2.COLOR_GRAY2BGR) 
img=cv2.bitwise_and(orig_image, cv2_image)
image_with_contours = img.copy()
#######################################

contours, hierarchy = cv2.findContours(binary_image.astype(np.uint8) ,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
cents=[]
quats_pca=[]
for contour in contours:
    # Draw contours on the image
    area = cv2.contourArea(contour)    
    if area > lower and area < higher :  #### AREA IN PIXELS ( USEFUL TO AVOID WALLS OR OTHER BIG CLUSTRS)
        print(area)        
        boundRect = cv2.boundingRect(contour)
        mask = np.zeros_like(binary_image) 
        mask=cv2.rectangle(mask,(boundRect[0], boundRect[1]),(boundRect[0]+boundRect[2], boundRect[1]+boundRect[3]), (255,255,255), -1)
        individual_mask=(mask*binary_image).astype(np.uint8)        
        cent=np.asarray(   ((  np.nanmean(corrected['x'][np.where(individual_mask==1)]) ,np.nanmean(corrected['y'][np.where(individual_mask==1)]),np.nanmean(corrected['z'][np.where(individual_mask==1)])       ))      )
        cents.append(cent)        
        ################################PCA
        points_c=np.asarray((corrected['x'][np.where(individual_mask==1)],corrected['y'][np.where(individual_mask==1)],corrected['z'][np.where(individual_mask==1)]))
        E_R=points_to_PCA(points_c.transpose())
        e_ER=tf.transformations.euler_from_matrix(E_R)
        quat= tf. transformations.quaternion_from_euler(e_ER[0],e_ER[1],e_ER[2])
        quats_pca.append(quat)
        print(np.rad2deg(tf.transformations.euler_from_matrix(E_R)))
        #######FOR DEBUG IMAGE
        cv2.drawContours(image_with_contours, contour, -1, (0, 255, 0), 2)  # -1 draws all contours
        rgb_image=cv2.rectangle(image_with_contours,(boundRect[0], boundRect[1]),(boundRect[0]+boundRect[2], boundRect[1]+boundRect[3]), (255,255,0), 2)

        
#plt.imshow(img)
plt.imshow (binary_image)

# %%
quats_pca, cents

# %%
#tf_map
for i, cent in enumerate(cents):
    x,y,z=cent
    axis=[0,0,1]
    angle = tf.transformations.euler_from_quaternion(quats_pca[i])[0]
    rotation_quaternion = tf.transformations.quaternion_about_axis(angle, axis)
    t=write_tf(    (x,y,z), rotation_quaternion, 'object'+str(i), "map"   )
    broadcaster.sendTransform(t)

# %%
for i, cent in enumerate(cents):
    x,y,z=cent
    t=write_tf(    (x,y,z), (0,0,0,1), 'ref'+str(i), "map"   )
    broadcaster.sendTransform(t)

# %%
new= np.zeros(img_z.shape)#mask
image= rgb_image.copy()
condition1 = (img_z > 0.39)
condition2 = (img_z < 0.41)
result_indices = np.where(np.logical_and(condition1, condition2))
image[result_indices]=np.asarray((0,0,255))

#new[np.where(img_z>=0.4)]=200
condition1 = (img_z > 0.405)
condition2 = (img_z < 0.70)
result_indices = np.where(np.logical_and(condition1, condition2))
new[result_indices]=200

plt.imshow(image)

# %%
_, binary_image = cv2.threshold(new, 20, 255, cv2.THRESH_BINARY)
cv2_image = cv2.cvtColor(binary_image.astype(np.uint8), cv2.COLOR_GRAY2BGR) 
plt.imshow(binary_image)

# %%
img=cv2.bitwise_and(rgb_image, cv2_image)
plt.imshow(img)

# %%
contours, hierarchy = cv2.findContours(binary_image.astype(np.uint8) ,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

# %%
lower=0 
higher=10000
image_with_contours = image.copy()
len(contours)
cents=[]
points=[]
for contour in contours:
    # Draw contours on the image
    area = cv2.contourArea(contour)    
    if area > lower and area < higher :  #### AREA IN PIXELS ( USEFUL TO AVOID WALLS OR OTHER BIG CLUSTRS)
        print(area)        
        boundRect = cv2.boundingRect(contour)
        mask = np.zeros_like(binary_image) 
        mask=cv2.rectangle(mask,(boundRect[0], boundRect[1]),(boundRect[0]+boundRect[2], boundRect[1]+boundRect[3]), (255,255,255), -1)
        individual_mask=(mask*binary_image).astype(np.uint8)        
        cent=np.asarray(   ((  np.nanmean(points_data['x'][np.where(individual_mask==1)]) ,np.nanmean(points_data['y'][np.where(individual_mask==1)]),np.nanmean(points_data['z'][np.where(individual_mask==1)])       ))      )
        cents.append(cent)
        cv2.drawContours(image_with_contours, contour, -1, (0, 255, 0), 2)  # -1 draws all contours
        rgb_image=cv2.rectangle(image_with_contours,(boundRect[0], boundRect[1]),(boundRect[0]+boundRect[2], boundRect[1]+boundRect[3]), (255,255,0), 2)
plt.imshow (image_with_contours)
print (cents)

# %%
for i, cent in enumerate(cents):
    x,y,z=cent
    t=write_tf(    (x,y,z), (0,0,0,1), 'object'+str(i), "head_rgbd_sensor_rgb_frame"   )
    broadcaster.sendTransform(t)

# %%
zs_no_nans=corrected['z'][~np.isnan(corrected['z'])]
histogram, bin_edges =(np.histogram(zs_no_nans, bins=100))
plane_height= bin_edges[histogram[:-1].argmax()]
print (plane_height)

# %%
hist,bins=np.histogram()])
plt.hist(img_z,bins=bins)

# %%
counts, bins =(np.histogram(zs_no_nans, bins=50))
inds=np.where(counts>5000)
low_planes_height=bins[np.add(inds, 1)].flatten()

low_planes_height2=bins[inds]

# %%
low_planes_height2.shape

# %%
 np.add(inds, 1)

# %%
zs_no_nans=corrected['z'][~np.isnan(corrected['z'])]
counts, bins =(np.histogram(zs_no_nans, bins=100))
inds=np.where(counts>5000)
print (f'Number of planes found {len(inds[0])} at z=[{bins[inds]}]')
plt.stairs(counts, bins)

# %%
np.where(counts>5000)

# %%
bins[np.where(counts>10000)]

# %%
condition1 = (img_z > 0.4)
condition2 = (img_z < 0.402)

result_indices = np.where(np.logical_or(condition1, condition2))

# %%
new[np.where(img_z<=.002)]=200
new[result_indices]=100

# %%
plt.imshow(new)

# %%
points_c=np.asarray((corrected['x'][np.where(individual_mask==1)],corrected['y'][np.where(individual_mask==1)],corrected['z'][np.where(individual_mask==1)]))
points_c.shape
E_R=points_to_PCA(points_c.transpose())
print(np.rad2deg(tf.transformations.euler_from_matrix(E_R)))

# %%
result_indices=()
for plane_height in bins[inds]:
    low_plane_ix = (corrected['z'] > plane_height)
    high_plane_ix = (corrected['z'] > plane_height + 0.3)

    result_indices += np.where(np.logical_or(low_plane_ix, high_plane_ix))

    print (plane_height )

# %%
len(result_indices[0])

# %%
high_plane = (corrected['z'] < 0.99)
result_indices = np.where(np.logical_and(low_plane, high_plane))
result_indices

# %%
 bins[inds].shape

# %%
low_planes= bins[inds]

# %%
for lp in low_planes:
    print (lp)

# %%
low_plane = (corrected['z'] > 0.7)      # HEIGHT REQUESTED OR OBTAINED FROM HISTOGRAM
high_plane = (corrected['z'] < 0.7+.3)

# %%
data=0.67

# %%
try:
        trans = tfBuffer.lookup_transform('map', 'head_rgbd_sensor_link', rospy.Time())

        trans,rot=read_tf(trans)
        #print ("############head",trans,rot)
except (tf2_ros.LookupException, tf2_ros.ConnectivityException, tf2_ros.ExtrapolationException):
        print ( 'No head TF FOUND')
t= write_tf(trans,rot)
cloud_out = do_transform_cloud(points_msg, t)
np_corrected=ros_numpy.numpify(cloud_out)
corrected=np_corrected.reshape(points_data.shape)
zs_no_nans=corrected['z'][~np.isnan(corrected['z'])]


###########################################
high_x = (corrected['x'] > 7.8)
low_x = (corrected['x'] < 8.25)###X COORDS
###############################################
#AUTO DETECT PLANE?
#if request.height.data==-1:
if data==-1:
    counts, bins =(np.histogram(zs_no_nans, bins=100))
    inds=np.where(counts>10000)
    planes_heights=bins[np.add(inds, 1)].flatten()
    print (f'Number of planes found {len(inds[0])} at z=[{bins[ np.add(inds, 1)]}]#############3')
    print (f'Plane heights detected {planes_heights} maximum  z=[{planes_heights.max()}]#############3')    
else:planes_heights=[data]
for plane_height in planes_heights:
    low_plane = (corrected['z'] > (plane_height-0.02)) #plane height
    high_plane = (corrected['z'] < (plane_height-0.02))#plane height + obj height
    orig_image= rgb_image.copy()
    mask= np.zeros(corrected['z'].shape)#mask
    z_lims=np.logical_and(low_plane, high_plane)
    x_lims=np.logical_and(low_x, high_x)
    result_indices = np.where(z_lims)#np.logical_and(z_lims, x_lims))
    mask[result_indices]=200
    _, binary_image = cv2.threshold(mask, 20, 255, cv2.THRESH_BINARY)
    eroded_image=cv2.erode(binary_image,kernel = np.ones((40, 40), np.uint8))
    print('np.where(eroded_image==255)',np.where(eroded_image==255))
    print ('quick estimation',np.nanmean(corrected['x'][np.where(eroded_image==255)]),np.nanmean(corrected['y'][np.where(eroded_image==255)]),np.nanmean(corrected['z'][np.where(eroded_image==255)]))
    contours, hierarchy = cv2.findContours(eroded_image.astype(np.uint8) ,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    cc=[]
    for contour in contours:
        M = cv2.moments(contour)
        area = cv2.contourArea(contour)
        if area > 200:                
        # calculate x,y coordinate of center
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
            cc.append((cX,cY))
            eroded_image=cv2.circle(binary_image, (cX, cY), 5, (200, 200, 200), -1)
    poses=[]
    for (cX,cY) in cc:
        x,y = cX,cY

        pose=np.asarray((np.mean(corrected['x'][y-15:y+15,x-15:x+15]), np.mean(corrected['y'][y-15:y+15,x-15:x+15]),np.mean(corrected['z'][y-15:y+15,x-15:x+15]) + 0.05))    
        binary_image[y-15:y+15,x-15:x+15]=100
        poses.append(pose)
        print('estimation', pose)
# Out:
# np.where(eroded_image==255) (array([], dtype=int64), array([], dtype=int64))
# quick estimation nan nan nan
# /tmp/ipykernel_51734/4219287226.py:40: RuntimeWarning: Mean of empty slice
#   print ('quick estimation',np.nanmean(corrected['x'][np.where(eroded_image==255)]),np.nanmean(corrected['y'][np.where(eroded_image==255)]),np.nanmean(corrected['z'][np.where(eroded_image==255)]))

# %%
np.where(eroded_image==255)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
plt.imshow(eroded_image)
