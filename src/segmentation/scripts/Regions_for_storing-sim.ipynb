# %%
from utils import *
import matplotlib.pyplot as plt
# Out:
# /home/roboworks/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
points_msg=rospy.wait_for_message("/hsrb/head_rgbd_sensor/depth_registered/rectified_points",PointCloud2,timeout=5)

# %%
points_data = ros_numpy.numpify(points_msg)    
image_data = points_data['rgb'].view((np.uint8, 4))[..., [2, 1, 0]]   
image=cv2.cvtColor(image_data, cv2.COLOR_BGR2RGB)
image = points_data['rgb'].view((np.uint8, 4))[..., [2, 1, 0]]
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
rgb_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb_image)

# %%
try:
        trans = tfBuffer.lookup_transform('map', 'head_rgbd_sensor_link', rospy.Time())
                    
        trans,rot=read_tf(trans)
        #print ("############head",trans,rot)
except (tf2_ros.LookupException, tf2_ros.ConnectivityException, tf2_ros.ExtrapolationException):
        print ( 'No head TF FOUND')
t= write_tf(trans,rot)
cloud_out = do_transform_cloud(points_msg, t)

# %%
np_corrected=ros_numpy.numpify(cloud_out)
corrected=np_corrected.reshape(points_data.shape)

# %%
plt.imshow(points_data['z'])

# %%
plt.imshow(corrected['z'])

# %%
img_z=corrected['z']
plt.imshow(img_z)

# %%
zs_no_nans=corrected['z'][~np.isnan(corrected['z'])]
counts, bins =(np.histogram(zs_no_nans, bins=100))
inds=np.where(counts>10000)
planes_heights=bins[np.add(inds, 1)].flatten()
print (f'Number of planes found {len(inds[0])} at z=[{bins[ np.add(inds, 1)]}]#############3')
print (f'Plane heights detected {planes_heights} maximum  z=[{bins[ np.add(np.argmax(counts) , 1)]}]#############3')

fig, ax = plt.subplots()
ax.bar(bins[:-1], counts, width=np.diff(bins), edgecolor="black", align="edge")

plt.show()
# Out:
# Number of planes found 3 at z=[[[0.06839298 0.4434691  0.8185452 ]]]#############3
# Plane heights detected [0.06839298 0.4434691  0.8185452 ] maximum  z=[0.4434691071510315]#############3

# %%
#plane_height=bins[ np.add(np.argmax(counts) , 1)]
print(f'plane height{plane_height}')
low_plane = (corrected['z'] > (plane_height-0.02)) #plane height
high_plane = (corrected['z'] < (plane_height+0.02))#plane height + obj height
z_lims=np.logical_and(low_plane, high_plane)
# Out:
# plane height0.4426966905593872

# %%
result_indices = np.where(z_lims)#np.logical_and(z_lims, x_lims))
x=np.asarray((corrected['x'][result_indices].min(),corrected['x'][result_indices].max())).reshape(-1, 1)
y=np.asarray((corrected['y'][result_indices].min(),corrected['y'][result_indices].max())).reshape(-1, 1)

region=np.append(x,y,axis=1)
print(f'region{region}')


rospack = rospkg.RosPack()        
file_path = rospack.get_path('config_files') 
np.save(file_path+'/regions/shelves_region_sim.npy',region)
#np.save(file_path+'/regions/pickup_region_sim.npy',region)
# Out:
# region[[3.6033392 1.2152985]
#  [4.052518  2.1063836]]
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 528.563000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 528.563000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 547.097000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 547.097000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 550.710000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 550.710000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 565.880000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 565.880000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 656.531000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 656.531000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 712.232000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 712.232000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 719.326000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 719.326000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 750.828000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 750.828000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 752.658000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 752.658000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 754.958000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 754.958000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 763.084000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 763.084000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 767.270000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 767.270000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 781.766000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 781.766000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 813.231000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 813.231000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 818.196000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 818.196000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 822.656000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 822.656000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 827.899000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 827.899000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 846.534000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 846.534000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 900.052000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 900.052000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 919.925000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 919.925000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 923.221000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 923.221000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 935.327000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 935.327000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 970.608000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 970.608000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 994.383000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 994.383000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 996.647000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 996.647000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1038.719000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1038.719000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1046.007000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1046.007000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1066.617000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1066.617000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1089.206000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1089.206000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1089.256000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1089.256000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1095.755000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1095.755000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1121.794000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1121.794000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1125.354000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1125.354000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1129.903000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1129.903000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1130.515000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1130.515000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1145.871000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1145.871000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1165.180000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 1165.180000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp

# %%
region
# Out:
# region[[3.4521677 1.23     ]
#  [4.0651736 2.1266067]]
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 472.346000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp
# Warning: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 472.346000 according to authority /pose_integrator
#          at line 278 in /tmp/binarydeb/ros-noetic-tf2-0.7.6/src/buffer_core.cpp

# %%
x,y
# Out:
# (array([[3.4521677],
#         [4.0651736]], dtype=float32),
#  array([[0.7583313],
#         [2.1266067]], dtype=float32))

# %%
y[0]=1.23

# %%
y
# Out:
# array([[1.23     ],
#        [2.1266067]], dtype=float32)
