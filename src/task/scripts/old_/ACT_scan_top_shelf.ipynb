# %%
from smach_utils2 import *
import matplotlib.pyplot as plt
#arm = moveit_commander.MoveGroupCommander('arm')
# Out:
# /home/roboworks/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
arm=moveit_commander.MoveGroupCommander('arm')
# Out:
# [ WARN] [1712595534.217298863]: Link hand_l_finger_vacuum_frame has visual geometry but no collision geometry. Collision geometry will be left empty. Fix your URDF file by explicitly specifying collision geometry.
# [ WARN] [1712595534.220055568]: Link head_l_stereo_camera_link has visual geometry but no collision geometry. Collision geometry will be left empty. Fix your URDF file by explicitly specifying collision geometry.
# [ WARN] [1712595534.220089322]: Link head_r_stereo_camera_link has visual geometry but no collision geometry. Collision geometry will be left empty. Fix your URDF file by explicitly specifying collision geometry.
# [ WARN] [1712595534.220803527]: Group state 'neutral' doesn't specify all group joints in group 'arm'. wrist_ft_sensor_frame_joint is missing.
# [ WARN] [1712595534.220843448]: Group state 'go' doesn't specify all group joints in group 'arm'. wrist_ft_sensor_frame_joint is missing.
# [ WARN] [1712595534.771774021]: Kinematics solver doesn't support #attempts anymore, but only a timeout.
# Please remove the parameter '/robot_description_kinematics/arm/kinematics_solver_attempts' from your configuration.
# [ WARN] [1712595535.013649382]: IK plugin for group 'whole_body' relies on deprecated API. Please implement initialize(RobotModel, ...).
# [ WARN] [1712595535.040763967]: IK plugin for group 'whole_body_weighted' relies on deprecated API. Please implement initialize(RobotModel, ...).
# [ WARN] [1712595535.071090245]: IK plugin for group 'whole_body_light' relies on deprecated API. Please implement initialize(RobotModel, ...).

# %%
whole_body=moveit_commander.MoveGroupCommander('whole_body_weighted')

# %%
high_shelf_place=np.asarray([0.15050079265248406,
 -0.5861087653247212,
 0.0850017715788356,
 -0.9342371117035135,
 0.022035143687695324,
 0.0])
mid_shelf_place=np.asarray([0.2556342351169577,
 -1.6040815280188854,
 -0.008078345343693893,
 -0.05795663028496589,
 0.0019971082238159354,
 0.0])

low_shelf_place=np.asarray([0.04577467546491997,
 -2.262541528018885,
 0.00010865465630605087,
 0.701618369715034,
 -0.0003068917761841483,
 0.0]
)

# %%
def categorize_objs(name):
    kitchen =['bowl','spatula','spoon', 'bowl','plate','h_cups']
    tools=['extra_large_clamp','large_clamp','small_clamp','medium_clamp','adjustable_wrench','flat_screwdriver','phillips_screwdriver','wood_block']
    balls= ['softball','tennis_ball','a_mini_soccer_ball', 'racquetball', 'golf_ball', 'baseball'  ]
    fruits= ['apple','banana', 'lemon','pear','plum','orange','f_cups']
    food =['chips_can','mustard_bottle','potted_meat_can','tomato_soup_can','tuna_fish_can','master_chef_can','sugar_box','pudding_box','cracker_box']
    if name in kitchen: return 'kitchen'
    elif name in tools: return 'tools'
    elif name in balls: return 'balls'
    elif name in fruits: return 'fruits'
    elif name in food: return 'food'
    return 'other'

# %%
request= segmentation_server.request_class() 

gripper.close()
gripper.steady()
arm.set_named_target('go')
arm.go()
res = omni_base.move_base(known_location='shelf', time_out=60)
# Out:
# [ WARN] [1712412942.835591480, 265.078000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 265.078000 according to authority /pose_integrator
# [ WARN] [1712412942.835678740, 265.078000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time
000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 278.149000 according to authority /pose_integrator
# [ WARN] [1712412972.995459435, 278.123000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 278.149000 according to authority /pose_integrator

# %%
head.set_joint_values([0.0 , 0.0])
av=arm.get_current_joint_values()
av[0]=0.65
av[1]=-0.5
arm.go(av)
head.set_joint_values([-np.pi/2 , -0.7])
request.height.data=0.87 

rospy.sleep(2.6)
image= cv2.cvtColor(rgbd.get_image(), cv2.COLOR_RGB2BGR)
img_msg  = bridge.cv2_to_imgmsg(image)
req      = classify_client.request_class()
req.in_.image_msgs.append(img_msg)
res      = classify_client(req)
debug_image=   cv2.cvtColor(bridge.imgmsg_to_cv2(res.debug_image.image_msgs[0]), cv2.COLOR_RGB2BGR)
objects=detect_object_yolo('all',res)  
objects
# Out:
# [ WARN] [1712412974.988853601, 279.057000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 279.077000 according to authority unknown_publisher
# [ WARN] [1712412974.989180230, 279.057000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 279.077000 according to authority /pose_integrator
# [ WARN] [1712412974.989248130, 279.057000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 279.077000 according to authority /pose_integrator
# [ WARN] [1712412974.989301221, 279.057000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 279.077000 according to authority /pose_integrator
# [ WARN] [1712412974.989347882, 279.057000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 279.077000 according to authority /pose_integrator
# [ WARN] [1712412974.989417205, 279.057000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 279.077000 according to authority /pose_integrator
# [ WARN] [1712412974.989476733, 279.057000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 279.077000 according to authority /pose_integrator
# [ WARN] [1712412977.250135603, 280.186000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.186000 according to authority /pose_integrator
# [ WARN] [1712412977.250192587, 280.186000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.186000 according to authority /pose_integrator
# [ WARN] [1712412977.250228961, 280.186000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.186000 according to authority /pose_integrator
# [ WARN] [1712412977.250271487, 280.186000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.186000 according to authority unknown_publisher
# [ WARN] [1712412977.250474137, 280.186000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.186000 according to authority /pose_integrator
# [ WARN] [1712412977.250541701, 280.186000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.186000 according to authority /pose_integrator
# [ WARN] [1712412977.250580326, 280.186000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.186000 according to authority /pose_integrator
# [ WARN] [1712412978.077264653, 280.525000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.553000 according to authority unknown_publisher
# [ WARN] [1712412978.077991411, 280.525000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.553000 according to authority /pose_integrator
# [ WARN] [1712412978.078049781, 280.525000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.553000 according to authority /pose_integrator
# [ WARN] [1712412978.078094347, 280.525000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.553000 according to authority /pose_integrator
# [ WARN] [1712412978.078138546, 280.525000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.553000 according to authority /pose_integrator
# [ WARN] [1712412978.078184407, 280.525000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.553000 according to authority /pose_integrator
# [ WARN] [1712412978.078234139, 280.525000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.553000 according to authority /pose_integrator
# [ WARN] [1712412978.870366936, 280.911000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.960000 according to authority unknown_publisher
# [ WARN] [1712412978.871572264, 280.911000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.960000 according to authority /pose_integrator
# [ WARN] [1712412978.873636762, 280.966000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.960000 according to authority /pose_integrator
# [ WARN] [1712412978.873731354, 280.966000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.960000 according to authority /pose_integrator
# [ WARN] [1712412978.873771054, 280.966000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.960000 according to authority /pose_integrator
# [ WARN] [1712412978.873823159, 280.966000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.960000 according to authority /pose_integrator
# [ WARN] [1712412978.873866203, 280.966000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 280.960000 according to authority /pose_integrator
# [ WARN] [1712412981.331709417, 282.125000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time
000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 895.152000 according to authority unknown_publisher
# [ WARN] [1712414444.053442166, 895.421000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 895.447000 according to authority unknown_publisher
# [ WARN] [1712414444.549134355, 895.651000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 895.683000 according to authority unknown_publisher
# [ WARN] [1712414446.376997614, 896.376000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 896.414000 according to authority unknown_publisher
# [ WARN] [1712414447.373267277, 896.760000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 896.789000 according to authority unknown_publisher
# [ WARN] [1712414447.540713051, 896.816000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 896.848000 according to authority unknown_publisher
# [ WARN] [1712414448.894327430, 897.319000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 897.340000 according to authority unknown_publisher
# [ WARN] [1712414449.156539635, 897.398000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 897.436000 according to authority unknown_publisher
# [ WARN] [1712414449.974578230, 897.754000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 897.812000 according to authority unknown_publisher
# [ WARN] [1712414450.099877624, 897.812000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 897.857000 according to authority unknown_publisher
# [ WARN] [1712414450.391810932, 897.925000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 897.972000 according to authority unknown_publisher
# [ WARN] [1712414450.551659613, 898.003000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 898.067000 according to authority unknown_publisher
# [ WARN] [1712414452.174849020, 898.769000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 898.788000 according to authority unknown_publisher
# [ WARN] [1712414453.121469978, 899.159000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 899.192000 according to authority unknown_publisher
# [ WARN] [1712414455.519980873, 900.030000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 900.046000 according to authority unknown_publisher
# [ WARN] [1712414457.471112927, 900.603000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 900.627000 according to authority unknown_publisher
# [ WARN] [1712414457.500910649, 900.635000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 900.679000 according to authority unknown_publisher
# [ WARN] [1712414457.728175449, 900.715000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 900.748000 according to authority unknown_publisher
# [ WARN] [1712414458.043138959, 900.836000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 900.884000 according to authority unknown_publisher
# [ WARN] [1712414459.401421432, 901.217000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 901.257000 according to authority unknown_publisher
# [ WARN] [1712414459.902326499, 901.384000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 901.434000 according to authority unknown_publisher
# [ WARN] [1712414460.180246599, 901.507000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 901.532000 according to authority unknown_publisher
# [ WARN] [1712414460.725343991, 901.661000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 901.681000 according to authority unknown_publisher
# [ WARN] [1712414463.706411839, 902.601000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 902.622000 according to authority unknown_publisher
# [ WARN] [1712414465.326883058, 903.122000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 903.165000 according to authority unknown_publisher
# [ WARN] [1712414466.115988022, 903.422000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 903.423000 according to authority unknown_publisher
# [ WARN] [1712414466.818200296, 903.658000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 903.690000 according to authority unknown_publisher
# [ WARN] [1712414467.456946231, 903.934000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 903.959000 according to authority unknown_publisher
# [ WARN] [1712414467.868082468, 904.059000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 904.100000 according to authority unknown_publisher
# [ WARN] [1712414468.368344239, 904.241000000]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 904.281000 according to authority unknown_publisher

# %%
plt.imshow(debug_image)

# %%
rospack = rospkg.RosPack()


file_path = rospack.get_path('config_files') 
objs = pd.read_csv (file_path+'/objects.csv')#EMPTY DATAFRAME
objs=objs.drop(columns='Unnamed: 0')

# %%
#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
if len (objects)!=0 :
    for i in range(len(res.poses)):
        #tf_man.getTF("head_rgbd_sensor_rgb_frame")
        position = [res.poses[i].position.x ,res.poses[i].position.y,res.poses[i].position.z]
        print ('position,name',position,res.names[i].data[4:])
        ##########################################################
        object_point = PointStamped()
        object_point.header.frame_id = "head_rgbd_sensor_rgb_frame"
        object_point.point.x = position[0]
        object_point.point.y = position[1]
        object_point.point.z = position[2]
        position_map = tfBuffer.transform(object_point, "map", timeout=rospy.Duration(1))
        print ('position_map',position_map.point.x,position_map.point.y,position_map.point.z)
        #tf_man.pub_static_tf(pos= [position_map.point.x,position_map.point.y,position_map.point.z], rot=[0,0,0,1], ref="map", point_name=res.names[i].data[4:] )
        new_row = {'x': position_map.point.x, 'y': position_map.point.y, 'z': position_map.point.z, 'obj_name': res.names[i].data[4:]}
        objs.loc[len(objs)] = new_row

# %%
objs

# %%
regions

# %%
top_shelf_height=0.7
def is_inside(x,y,z):return ((area_box[:,1].max() > y) and (area_box[:,1].min() < y)) and ((area_box[:,0].max() > x) and (area_box[0,0].min() < x)       ) and ((top_shelf_height*1.1 > z) and (0.9*top_shelf_height < z)       )

area_box=regions['shelves']
in_region=[]
cats=[]
for index, row in objs[['x','y','z']].iterrows():in_region.append(is_inside(row.x, row.y,row.z))
objs['top_shelf']=pd.Series(in_region)
for name in objs['obj_name']:cats.append(categorize_objs(name))
objs['category'] = cats 
objs

# %%
objs[objs['top_shelf']]

# %%
shelves_cats={}
a=objs[objs['top_shelf']]['category'].value_counts()
if 'other' in objs[objs['top_shelf']]['category'].values:a.drop('other',inplace=True)
if len(a.values)!=0:
    print(f'btm shelf category {a.index[a.argmax()]}')
    shelves_cats['top'] =a.index[a.argmax()]

# %%
shelves_cats

# %%
a= sh_o_btm['category'].value_counts()
            if 'other' in objs[objs['top_shelf']]['category'].values:a.drop('other', inplace=True)
            if len(a.values)!=0:
                print(f'btm shelf category {a.index[a.argmax()]}')
                shelves_cats.append(a.index[a.argmax()])

# %%
objs[objs['top_shelf']]['category'].values

# %%
a

# %%
a=objs[objs['top_shelf']]['category'].value_counts()
if 'other' in objs[objs['top_shelf']]['category'].values:a.drop('other',inplace=True)

# %%
a

# %%
regions['shelves']=np.load('/home/roboworks/Documents/pickup_shelf_sim.npy')

# %%
regions

# %%
rospack = rospkg.RosPack()
file_path = rospack.get_path('config_files')              
regions={'shelves':np.load(file_path+'/shelves_region.npy'),'pickup':np.load(file_path+'/pickup_region.npy')}

# %%
regions['shelves'][:,0]=[]

# %%
head.set_joint_values([-np.pi/2 , -0.7])
request.height.data=0.87 
arm.set_named_target('go')
arm.go()

# %%
plt.imshow(debug_image)

# %%
request= segmentation_server.request_class() 

print ('#############Finding placing in plane####################',request.height.data)
#request.height.data=-1
request.height.data=0.38  #MID SHELF FOR PLACING SIM
request.height.data=0.42  #MID SHELF FOR PLACING REAL
area_name_numbered= 'mid_shelf'


res=placing_finder_server.call(request)
#succ=seg_res_tf(res)
print (f'Placing Area at {res.poses.data}')
tf_man.pub_static_tf(pos=[res.poses.data[0], res.poses.data[1],res.poses.data[2]], rot =[0,0,0,1], point_name='placing_area')
img=bridge.imgmsg_to_cv2(res.im_out.image_msgs[0])
#cv2.imshow('our of res'  , img)
plt.imshow(img)

# %%
res = omni_base.move_base(known_location='place_shelf', time_out=12)

# %%
base_grasp_D(tf_name='placing_area',d_x=0.76, d_y=0.0,timeout=30)
arm.go (mid_shelf_place)
hand_graspD()
gripper.open()
omni_base.tiny_move(velX=-0.3 ,std_time=3.0)
gripper.steady()

arm.set_named_target('go')
arm.go()

# %%
gripper.open()
omni_base.tiny_move(velX=-0.3 ,std_time=3.0)
gripper.steady()

arm.set_named_target('go')
arm.go()

# %%
hand_graspD()

# %%
def hand_graspD(tf_name='placing_area',timeout=30.0):
    
    timeout = rospy.Time.now().to_sec() + timeout
    succ=False
    THRESHOLD = 0.03
    _,rot = tf_man.getTF(target_frame='placing_area', ref_frame='hand_palm_link')
    original_rot=tf.transformations.euler_from_quaternion(rot)[2]
    while (timeout >= rospy.Time.now().to_sec()) and not succ and not rospy.is_shutdown():
        trans,rot = tf_man.getTF(target_frame='placing_area', ref_frame='hand_palm_link')
        if type(trans) is not bool:
            _, eY, eX = trans

            if abs(eY) < THRESHOLD:
                eY = 0
            if abs(eX) < 0.07:
                eX = 0
            eT= tf.transformations.euler_from_quaternion(rot)[2] - original_rot #Original 
            print("Distance to goal: {:.2f}, {:.2f}, {:.2f}".format(eX, eY,eT))

            if eT > np.pi: eT=-2*np.pi+eT
            if eT < -np.pi: eT= 2*np.pi+eT
            if abs(eT) < 0.12:
                eT=0
            
            print("error: {:.2f}, {:.2f}, angle {:.2f}, target obj frame placing area".format(eX, eY , eT))
            succ =  eX == 0 and eY == 0 and eT==0            
            
                # grasp_base.tiny_move(velY=-0.4*trans[1], std_time=0.2, MAX_VEL=0.3)
            omni_base.tiny_move(velX=0.13*eX, velY=-0.4*eY, std_time=0.2, MAX_VEL=0.3) #Pending test
    return succ

# %% [markdown]
# # here

# %%
head.set_joint_values([-1.5,-0.65])
rospy.sleep(0.5)
request= segmentation_server.request_class() 
plane_height=0.40

#request.height.data=-1
request.height.data=plane_height  #MID SHELF FOR PLACING 
print ('#############Finding placing in plane####################',request.height.data)
area_name_numbered= 'mid_shelf'


res=placing_finder_server.call(request)
#succ=seg_res_tf(res)

print (f'Placing Area at {res.poses.data}')
if len(res.poses.data)!=0:
    tf_man.pub_static_tf(pos=[res.poses.data[0], res.poses.data[1],res.poses.data[2]], rot =[0,0,0,1], point_name='placing_area')
    img=bridge.imgmsg_to_cv2(res.im_out.image_msgs[0])
else:
    request.height.data=plane_height+0.02  #MID SHELF FOR PLACING 
    print ('#############Finding placing in plane####################',request.height.data)
    res=placing_finder_server.call(request)
    print (f'Placing Area at {res.poses.data}')
    if len(res.poses.data)!=0:
        tf_man.pub_static_tf(pos=[res.poses.data[0], res.poses.data[1],res.poses.data[2]], rot =[0,0,0,1], point_name='placing_area')
        img=bridge.imgmsg_to_cv2(res.im_out.image_msgs[0])
    else:
        request.height.data=plane_height+0.04  #MID SHELF FOR PLACING 
        print ('#############Finding placing in plane####################',request.height.data)
        area_name_numbered= 'mid_shelf'
        if len(res.poses.data)!=0:
            print ('gotit')
            tf_man.pub_static_tf(pos=[res.poses.data[0], res.poses.data[1],res.poses.data[2]], rot =[0,0,0,1], point_name='placing_area')
            img=bridge.imgmsg_to_cv2(res.im_out.image_msgs[0])
        else:print('failed')

# %%
len(res.poses.data)

# %%
base_grasp_D(tf_name='placing_area',d_x=0.76, d_y=0.0,timeout=30)
arm.go (mid_shelf_place)
base_grasp_D(tf_name='placing_area',d_x=0.6, d_y=0.0,timeout=30)
gripper.open()

# %%
arm.go (mid_shelf_place)

# %%
base_grasp_D(tf_name='placing_area',d_x=0.6, d_y=0.0,timeout=30)
gripper.open()

# %%
for i in range(len(res.poses)):
    tf_man.getTF("head_rgbd_sensor_rgb_frame")
    tf_man.pub_static_tf(pos=[res.poses[i].position.x ,res.poses[i].position.y,res.poses[i].position.z], rot=[0,0,0,1],ref="head_rgbd_sensor_rgb_frame",point_name=res.names[i].data[4:] )   
    rospy.sleep(0.3)
    tf_man.change_ref_frame_tf(res.names[i].data[4:])

# %%
omni_base.move_d_to(target_distance=0.78,target_link='apple')

# %%
target_object='apple'
trans,_=tf_man.getTF(target_object,ref_frame="base_link")
trans

# %%
target_object='apple'
_,rot= tf_man.getTF("base_link",ref_frame='map')

original_rot=tf.transformations.euler_from_quaternion(rot)[2]
trans,_=tf_man.getTF(target_object,ref_frame="base_link")


trans , original_rot

# %%
_,rot= tf_man.getTF("base_link",ref_frame='map')
original_rot=tf.transformations.euler_from_quaternion(rot)[2]
target_object='apple'


succ = False
            
while not succ:
    
    _,rot= tf_man.getTF("base_link",ref_frame='map')
    trans,_=tf_man.getTF(target_object,ref_frame="base_link")

    trans
    eX, eY, eZ = trans
    
    eX+= -0.4
    eY+= -.06
    
    eT= tf.transformations.euler_from_quaternion(rot)[2] - original_rot #Original 
    print (eT)
    if eT > np.pi: eT=-2*np.pi+eT
    if eT < -np.pi: eT= 2*np.pi+eT
    rospy.loginfo("error: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(eX, eY , eT,target_object))
    X, Y, Z = trans
    rospy.loginfo("Pose: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(X, Y , eT,target_object))
    
    if abs(eX) <=0.05 :
        print ('here')
        eX = 0
    if abs(eY) <=0.05  :
        eY = 0
    if abs(eT   ) < 0.1:
        eT = 0
    succ =  eX == 0 and eY == 0 and eT==0

    
    omni_base.tiny_move( velX=0.2*+eX,velY=0.3*eY, velT=-eT,std_time=0.2, MAX_VEL=0.3)

# %%
res.names

# %%
hand_cam= HAND_RGB()

# %%
#clear_octo_client()

pickup_pose=[0.65,-1.2,0.0,-1.9, 0.0, 0.0]
succ= arm.go(pickup_pose)
gripper.open()

# %%
image= cv2.cvtColor(hand_cam.get_image(), cv2.COLOR_RGB2BGR)
img_msg  = bridge.cv2_to_imgmsg(image)
req      = classify_client.request_class()
req.in_.image_msgs.append(img_msg)
res      = classify_client(req)
debug_image=   cv2.cvtColor(bridge.imgmsg_to_cv2(res.debug_image.image_msgs[0]), cv2.COLOR_RGB2BGR)
for i in range(len(res.names)):
    if res.names[i].data== '013_apple' or res.names[i].data== '017_orange':
        bbM=res.pt_min.data[2*i:2*i+2]
        bbm=res.pt_max.data[2*i:2*i+2]
        bbx=[bbM,bbm]
print(bbx)
plt.imshow(debug_image)

# %% [markdown]
# # [(297, 191), (231, 226)]  at pkcp pose #Real Tak
# ### [(323, 266), (280, 215)]  at pkcp pose #Gazebo

# %%
eX,eY= 0.3,0.3 

while abs(eX) > 0.05 or abs(eY) > 0.05:
    image= cv2.cvtColor(hand_cam.get_image(), cv2.COLOR_RGB2BGR)
    img_msg  = bridge.cv2_to_imgmsg(image)
    req      = classify_client.request_class()
    req.in_.image_msgs.append(img_msg)
    res      = classify_client(req)


    for i in range(len(res.names)):
        if res.names[i].data== '013_apple' or res.names[i].data== '017_orange':
            bbM=res.pt_min.data[2*i:2*i+2]
            bbm=res.pt_max.data[2*i:2*i+2]
            bbx=[bbM,bbm]
    print(bbx)
    eY=(bbx[1][1]-215)/215    #experience value
    #print(f'error relative to gripper cam {eY}')


    #eX=(bbx[0][0]-323)/323
    eY=(bbx[1][1]-239)/239
    eX=(bbx[0][0]-312)/312
    #eY=(bbx[1][1]-215)/215    #experience value

    print(f'error relative to gripper cam ex={eX} ey={eY}')
    omni_base.tiny_move(velX=0.5*eX, velY=0.5*-eY, MAX_VEL=0.05) 
print(f'error relative to gripper cam ex={eX} ey={eY}:::::: Error within tolerance')

# %%
bbx

# %%
eY=(bbx[1][1]-239)/239
eX=(bbx[0][0]-312)/312
print(f'error relative to gripper cam ex={eX} ey={eY}')

# %%
#omni_base.tiny_move(velX=0.5*eX, velY=0.5*-eY, MAX_VEL=0.05)

# %%
clear_octo_client()

av=arm.get_current_joint_values()
print (av,'av')
av[0]+= -0.17###LAB
#av[0]+= -0.35###GAZ
succ=arm.go(av)
rospy.sleep(0.5)
gripper.close(force=0.06)

# %%
av=arm.get_current_joint_values()
print (av,'av')
av[0]+= 0.15
succ=arm.go(av)
omni_base.tiny_move(velX=-0.3, std_time=4.0)
arm.set_named_target('go')
arm.go()
#tf_man.pub_static_tf(point_name='apple')

# %%
plt.imshow(hand_cam.get_image())

# %%
image= cv2.cvtColor(hand_cam.get_image(), cv2.COLOR_RGB2BGR)
img_msg  = bridge.cv2_to_imgmsg(image)
req      = classify_client.request_class()
req.in_.image_msgs.append(img_msg)
res      = classify_client(req)
debug_image=   cv2.cvtColor(bridge.imgmsg_to_cv2(res.debug_image.image_msgs[0]), cv2.COLOR_RGB2BGR)
plt.imshow(debug_image)

# %%
gripper.open()

# %%
gripper.close(force=0.06)

# %%
for i in range(len(res.poses)):
    tf_man.getTF("head_rgbd_sensor_rgb_frame")
    position = [res.poses[i].position.x ,res.poses[i].position.y,res.poses[i].position.z]
    tf_man.pub_static_tf(pos= position, rot=[0,0,0,1], ref="head_rgbd_sensor_rgb_frame", point_name=res.names[i].data[4:] )   
    rospy.sleep(0.3)
    tf_man.change_ref_frame_tf(res.names[i].data[4:])

# %%
def detect_object_yolo(object_name,res):
    # find object_name in the response message from object_classification service (Yolo)
    objs=[]
    for i,name in enumerate(res.names):
        objs.append(name.data[4:])
        if name.data[4:]==object_name:return res.poses[i]
    if object_name=='all':
        
        return objs
    return []

# %%
#img_msg  = bridge.cv2_to_imgmsg(rgbd.get_image())  #REAL
img_msg  = bridge.cv2_to_imgmsg(cv2.cvtColor(rgbd.get_image(), cv2.COLOR_RGB2BGR ))#GAZEB
req      = classify_client.request_class()
req.in_.image_msgs.append(img_msg)
res      = classify_client(req)
objects=detect_object_yolo('all',res)   
if len (objects)!=0:
    for i in range(len(res.poses)):
        tf_man.getTF("head_rgbd_sensor_rgb_frame")
        position = [res.poses[i].position.x ,res.poses[i].position.y,res.poses[i].position.z]
        tf_man.pub_static_tf(pos= position, rot=[0,0,0,1], ref="head_rgbd_sensor_rgb_frame", point_name=res.names[i].data[4:] )   
        rospy.sleep(0.3)
        tf_man.change_ref_frame_tf(res.names[i].data[4:])
        rospy.sleep(0.3)
        pose , _=tf_man.getTF(res.names[i].data[4:])
        new_row = {'x': pose[0], 'y': pose[1], 'z': pose[2], 'obj_name': res.names[i].data[4:]}
        objs.loc[len(objs)] = new_row
objs

# %%
objs[['x','y','z']].values

# %%
#get closest object
rob_pos,_=tf_man.getTF('base_link')
np.argmin(np.linalg.norm(rob_pos-objs[['x','y','z']].values  , axis=1))
objs.iloc[np.argmin(np.linalg.norm(rob_pos-objs[['x','y','z']].values  , axis=1))]['obj_name']

# %%
objs[objs['obj_name']==objs.obj_name.values[0]].x.values[0]

# %% [markdown]
# # PLANE 1
# #### 7.883384	5.948245	0.701945,
# #### 8.214565	5.962619	0.700034,
# #### 8.213697	6.107727	0.709487,
# ####  7.893623	6.082935	0.693285

# %% [markdown]
# # PLANE 2
# #### 7.88076	6.086619	0.416096,
# #### 8.214128	5.9663	0.416672

# %% [markdown]
# # Plane 3
# #### 8.20238	5.963262	0.117541

# %%
head.set_named_target('neutral')

av=arm.get_current_joint_values()
av[0]=0.5
av[1]=-0.5
arm.go(av)
head.set_joint_values([-np.pi/2 , -0.5])

# %%
head.set_joint_values([-np.pi/2 , -0.5])

# %%
av=arm.get_current_joint_values()
av[0]=0.05

arm.go(av)

# %%
head.set_joint_values([-np.pi/2 , -0.8])

av=arm.get_current_joint_values()
av[0]=0.0
av[1]=-0.5
arm.go(av)

# %%
import pandas as pd

# %%
import pandas as pd
objs = pd.read_csv ('/home/roboworks/Documents/objs.csv')
objs=objs.drop(columns='Unnamed: 0')

# %%
objs=objs[objs['obj_name'] != 'bowl']

# %%
objs

# %%
objs[objs['obj_name'] != 'bowl']

# %%
objs

# %%
from sklearn.cluster import KMeans
shelf_objs=objs[objs['shelves']==True ]
sh_o_btm=shelf_objs[shelf_objs['z']<0.2]

# %%
'other' in sh_o_top['category'].values

# %%
shelf_objs=objs[objs['shelves']==True ]

sh_o_btm=shelf_objs[shelf_objs['z']<0.2]
sh_o_mdl=shelf_objs[(shelf_objs['z']>0.2 )& (shelf_objs['z']<0.5) ]
sh_o_top=shelf_objs[(shelf_objs['z']>0.5 )& (shelf_objs['z']<1.5) ]
sh_o_btm['category'].value_counts(),sh_o_mdl['category'].value_counts() 

a= sh_o_btm['category'].value_counts()
if 'other' in sh_o_btm['category'].values:a.drop('other', inplace=True)
print(f'btm shelf category {a.index[a.argmax()]}')

a= sh_o_mdl['category'].value_counts()
if 'other' in sh_o_mdl['category'].values:a.drop('other', inplace=True)
print(f'middle shelf category {a.index[a.argmax()]}')


a= sh_o_top['category'].value_counts()
if 'other' in sh_o_top['category'].values:a.drop('other', inplace=True)
print(f'top shelf category {a.index[a.argmax()]}')

# %%
a

# %%
kitchen =['bowl','spatula','spoon', 'bowl']
tools=['extra_large_clamp','large_clamp','small_clamp','medium_clamp','adjustable_wrench',
'flat_screwdriver','phillips_screwdriver','wood_block']
balls= ['softball','tennis_ball']
fruits= ['apple','banana', 'lemon','pear']
food =['chips_can'
,'mustard_bottle'
,'potted_meat_can'
,'tomato_soup_can'
,'tuna_fish_can']

def categorize_objs(name):
    if name in kitchen: return 'kitchen'
    elif name in tools: return 'tools'
    elif name in balls: return 'balls'
    elif name in fruits: return 'fruits'
    elif name in food: return 'food'
    return 'other'
cats=[]
for name in objs['obj_name']:
    cats.append(categorize_objs(name))
objs['category'] = cats

# %%
def categorize_objs(name):
    if name in kitchen: return 'kitchen'
    elif name in tools: return 'tools'
    elif name in balls: return 'balls'
    elif name in fruits: return 'fruits'
    elif name in food: return 'food'
    return 'other'

# %%
cats=[]
for name in objs['obj_name']:
    cats.append(categorize_objs(name))
objs['category'] = cats

# %%
objs

# %%
import numpy as np
regions={'shelves':np.load('/home/roboworks/Documents/shelf_sim.npy'),'pickup':np.load('/home/roboworks/Documents/pickup_sim.npy')}
def is_inside(x,y):return ((area_box[:,1].max() > y) and (area_box[:,1].min() < y)) and ((area_box[:,0].max() > x) and (area_box[0,0].min() < x)) 
for name in regions:
    in_region=[]
    area_box=regions[name]
    print (area_box,name)
    for index, row in objs[['x','y','z']].iterrows():
        in_region.append(is_inside(row.x, row.y))
        print (row.x, row.y,is_inside(row.x, row.y))
    objs[name]=pd.Series(in_region)
objs

# %%
(area_box[:,1].max() > row.y),(area_box[:,1].min() < row.y),((area_box[:,0].max() > row.x) , (area_box[0,0].min() < row.x))

# %%
def is_inside(x,y):return ((area_box[:,1].max() > y) and (area_box[:,1].min() < y)) and ((area_box[:,0].max() > x) and (area_box[0,0].min() < x))

# %%
pickup_region=np.zeros((2,2))
#np.save('/home/roboworks/Documents/pickup_region.npy', pickup_region)

# %%
ab[0,0],ab[0,1]=6,6
ab[1,0],ab[1,1]=7,4.0

# %%
import numpy as np

#ab=np.load('/home/roboworks/Documents/pickup_region.npy')
ab= np.load('/home/roboworks/Documents/pickup_sim.npy')

# %%
ab[0,0]=5.8
ab

# %%
np.save('/home/roboworks/Documents/pickup_region.npy',ab)

# %%
#np.save('/home/roboworks/Documents/shelf_sim.npy',ab)
np.save('/home/roboworks/Documents/pickup_sim.npy',ab)

# %%
objs[objs['pickup']==True][['x','y','z']].values

# %%
rob_pos,_=tf_man.getTF('base_link')
ix=np.argmin(np.linalg.norm(rob_pos-objs[objs['pickup']==True][['x','y','z']].values  , axis=1))
ix

# %%
rob_pos,_=tf_man.getTF('base_link')
ix=np.argmin(np.linalg.norm(rob_pos-objs[objs['pickup']==True][['x','y','z']].values  , axis=1))
objs[objs['pickup']==True][['obj_name','category']].iloc[ix]

# %%
ix=np.argmin(np.linalg.norm(rob_pos-objs[objs['pickup']==True][['x','y','z']].values  , axis=1))

# %%
pose=np.asarray((8.212561, 6.028789, 0.12))
pose

# %%
tf_man.pub_static_tf(pos=pose,point_name='PLACING')

# %%
#pose=np.asarray((8.212561, 6.028789, 0.12))
pose=np.asarray((8.062455, 6.0622816, 0.6610926))
tf_man.pub_static_tf(pos=pose,point_name='PLACING')

# %%
arm['arm_lift_joint']=0.0

# %%
omni_base.move_base(known_location='shelf')

# %%
omni_base.tiny_move(velT=-0.7,std_time=1)

# %%
av=arm.get_current_joint_values()
high_shelf_place=av
high_shelf_place

# %%
place_high_shelf=np.asarray([0.15050079265248406,
 -0.5861087653247212,
 0.0850017715788356,
 -0.9342371117035135,
 0.022035143687695324,
 0.0])

# %%
arm.go(place_high_shelf)

# %% [markdown]
# av=arm.get_current_joint_values()

# %%
av=arm.get_current_joint_values()
high_shelf_place=av

# %%
arm.go(high_shelf_place)

# %%
av=arm.get_current_joint_values()
mid_shelf_place=av
mid_shelf_place

# %%
av=arm.get_current_joint_values()
low_shelf_place=av
low_shelf_place

# %%
high_shelf_place,low_shelf_place,mid_shelf_place

# %%
high_shelf_place=np.asarray([0.4337121304669095,
 -1.3139266720690426,
 0.08621383272112926,
 -0.4260850221072081,
 0.02285051353933021,
 0.0])

# %%
low_shelf_place=np.asarray([-5.465250513158978e-07,
 -1.8875162206087301,
 0.08646571240675005,
 0.3040738848075222,
 0.022992974203400962,
 0.0]
)

# %%
high_shelf_place=np.asarray([0.15050079265248406,
 -0.5861087653247212,
 0.0850017715788356,
 -0.9342371117035135,
 0.022035143687695324,
 0.0])
mid_shelf_place=np.asarray([0.2556342351169577,
 -1.6040815280188854,
 -0.008078345343693893,
 -0.05795663028496589,
 0.0019971082238159354,
 0.0])

low_shelf_place=np.asarray([0.04577467546491997,
 -2.262541528018885,
 0.00010865465630605087,
 0.701618369715034,
 -0.0003068917761841483,
 0.0]
)

# %%
tf_man.getTF('placing_area_top_shelf1')

# %%
request= segmentation_server.request_class() 
#r = cv2.getTrackbarPos('Plane height (cms)', 'class rgbd')
#request.height.data=0.9
print ('#############Finding placing in plane####################',request.height.data)
request.height.data=-1
#head.set_joint_values([ 0.1, -0.5])
res=placing_finder_server.call(request)
#succ=seg_res_tf(res)
print (f'Placing Area at {res.poses.data}')
tf_man.pub_static_tf(pos=[res.poses.data[0], res.poses.data[1],res.poses.data[2]], rot =[0,0,0,1], point_name='placing_area')
img=bridge.imgmsg_to_cv2(res.im_out.image_msgs[0])
#cv2.imshow('our of res'  , img)
plt.imshow(img)

# %%
tf_man.getTF('placing_area')

# %%
head.set_named_target('neutral')

# %%
arm.set_named_target('go')
arm.go()

# %%
res = omni_base.move_base(known_location='place_shelf', time_out=10)

# %%
high_shelf_place=[0.65,         -1.139,         0.08621,        -0.4260,        0.02285,         0.0]#REAL
high_shelf_place=[0.4337,         -1.3139,         0.08621,        -0.4260,        0.02285,         0.0] #GAZ

# %%
arm.set_joint_value_target(high_shelf_place)
arm.go()

# %%
def base_grasp_D(tf_name,d_x=0.66,d_y=-0.1,timeout=1.0):
    timeout = rospy.Time.now().to_sec() + timeout
    rob_pos,rot=tf_man.getTF('base_link')    
    original_rot=tf.transformations.euler_from_quaternion(rot)[2]
    succ = False 
    target_object= tf_name        
    while (timeout >= rospy.Time.now().to_sec()) and not succ:            
        _,rot= tf_man.getTF("base_link",ref_frame='map')
        trans,_=tf_man.getTF(target_object,ref_frame="base_link")
        #trans
        eX, eY, eZ = trans
        eX+= -d_x  #x offest
        eY+= -d_y #y Offset
        eT= tf.transformations.euler_from_quaternion(rot)[2] - original_rot #Original 
        print (eT)
        if eT > np.pi: eT=-2*np.pi+eT
        if eT < -np.pi: eT= 2*np.pi+eT
        rospy.loginfo("error: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(eX, eY , eT,target_object))
        X, Y, Z = trans
        rospy.loginfo("Pose: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(X, Y , eT,target_object))
        if abs(eX) <=0.05 :
            print ('here')
            eX = 0
        if abs(eY) <=0.05  :
            eY = 0
        if abs(eT   ) < 0.1:
            eT = 0
        succ =  eX == 0 and eY == 0 and eT==0            
        omni_base.tiny_move( velX=0.2*+eX,velY=0.3*eY, velT=-eT,std_time=0.2, MAX_VEL=0.3)

# %%
tf_man.getTF('placing_area')

# %%
base_grasp_D(tf_name='placing_area')

# %%
base_grasp_D(tf_name='placing_area',d_x=0.76, d_y=0.0,timeout=30)

# %%
gripper.open()

# %%
target_object='placing_area'
_,rot= tf_man.getTF("base_link",ref_frame='map')
trans,_=tf_man.getTF(target_object,ref_frame="base_link")

 
eX, eY, eZ = trans
eT= tf.transformations.euler_from_quaternion(rot)[2] - original_rot #Original 
print (eT)
if eT > np.pi: eT=-2*np.pi+eT
if eT < -np.pi: eT= 2*np.pi+eT
rospy.loginfo("error: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(eX, eY , eT,target_object))
X, Y, Z = trans
rospy.loginfo("Pose: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(X, Y , eT,target_object))

# %%
omni_base.tiny_move( velX=0.1*+eX,velY=0.1*eY, velT=-eT,std_time=0.2, MAX_VEL=0.3)

# %%
d_x=0.58
d_y= 0.1
_,rot= tf_man.getTF("base_link",ref_frame='map')
trans,_=tf_man.getTF(target_object,ref_frame="base_link")
#trans
eX, eY, eZ = trans
eX+= -d_x  #x offest
eY+= -d_y #y Offset
eT= tf.transformations.euler_from_quaternion(rot)[2] - original_rot #Original 
print (eT)
if eT > np.pi: eT=-2*np.pi+eT
if eT < -np.pi: eT= 2*np.pi+eT
rospy.loginfo("error: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(eX, eY , eT,target_object))
X, Y, Z = trans
rospy.loginfo("Pose: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(X, Y , eT,target_object))
if abs(eX) <=0.05 :
    print ('here')
    eX = 0
if abs(eY) <=0.05  :
    eY = 0
if abs(eT   ) < 0.1:
    eT = 0
succ =  eX == 0 and eY == 0 and eT==0      
succ
#omni_base.tiny_move( velX=0.2*+eX,velY=0.3*eY, velT=-eT,std_time=0.2, MAX_VEL=0.3)

# %%
omni_base.tiny_move( velX=0.1*+eX,velY=0.1*eY, velT=-eT,std_time=0.2, MAX_VEL=0.3)

# %%
arm.get_current_pose()

# %%
av=arm.get_current_joint_values()
av[0]+=-0.1
arm.go(av)

# %%
arm.set_named_target('go')
arm.go()

# %%
omni_base.move_base('place_shelf')

# %%
whole_body.allow_replanning(True)
whole_body.set_num_planning_attempts(10)
whole_body.set_planning_time(10.0)
whole_body.set_workspace([-2.0, -2.0, 0.0, 2.0, 2.0, 2.0])

# %%
object_point = PointStamped()
object_point

# %%
target_position=[1.0,1.0,1.0]
object_point = PointStamped()
object_point.header.frame_id = "base_link"
object_point.point.x = target_position[0]
object_point.point.y = target_position[1]
object_point.point.z = target_position[2]
#transformar la posicion del objeto al marco de referencia de la base del robot

try:
    transformed_object_point = tfBuffer.transform(object_point, "base_link", timeout=rospy.Duration(1))
    transformed_base = self.tfBuffer.lookup_transform("odom", "base_link", rospy.Time(0), timeout=rospy.Duration(1))
except :
    rospy.WARN("Error al transformar la posicion del objeto al marco de referencia")

# %%
tfBuffer.transform(object_point,'base_link',timeout=rospy.Duration(3))

# %%
whole_body.set_start_state_to_current_state()
whole_body.set_position_target(position_goal)
succ = whole_body.go(wait= True)
rospy.sleep(0.5)
whole_body.stop()

# %%
tfBuffer = tf2_ros.Buffer()

# %%
omni_base.move_base(known_location='pickup', time_out=200)

# %%
head.set_joint_values([ 0.0, -0.5])

# %%
img_msg  = bridge.cv2_to_imgmsg( cv2.cvtColor(rgbd.get_image(), cv2.COLOR_RGB2BGR))### GAZEBO BGR!?!??!
req      = classify_client.request_class()
req.in_.image_msgs.append(img_msg)
res      = classify_client(req)
objects=detect_object_yolo('all',res)

# %%
rospack = rospkg.RosPack()
file_path = rospack.get_path('config_files') 
objs = pd.read_csv (file_path+'/objects.csv')
objs=objs.drop(columns='Unnamed: 0')
print (objs)

# %%
def check_if_grasped(pose_target,test_pt,tolerance=0.05):    
    return np.linalg.norm(pose_target-obj_pt)<tolerance

# %%
np.linalg.norm(pose_target-obj_pt)

# %%
test_pt=objs[objs['obj_name']=='orange'][['x','y','z']].values
check_if_grasped(pose_target,test_pt)

# %%
def check_if_grasped(pose_target,test_pt,tolerance=0.05):return np.linalg.norm(pose_target-test_pt)<tolerance


##############################
pose_target,_=tf_man.getTF('plum')
#########################

if len (objects)!=0 :
    for i in range(len(res.poses)):
        
        position = [res.poses[i].position.x ,res.poses[i].position.y,res.poses[i].position.z]
        
        object_point = PointStamped()
        object_point.header.frame_id = "head_rgbd_sensor_rgb_frame"
        object_point.point.x = position[0]
        object_point.point.y = position[1]
        object_point.point.z = position[2]
        position_map = tfBuffer.transform(object_point, "map", timeout=rospy.Duration(1))
        
        tf_man.pub_static_tf(pos= [position_map.point.x,position_map.point.y,position_map.point.z], rot=[0,0,0,1], ref="map", point_name=res.names[i].data[4:] )
        test_pt=np.asarray((position_map.point.x,position_map.point.y,position_map.point.z))
        print (np.linalg.norm(pose_target-test_pt))
        if check_if_grasped(pose_target,test_pt):
            print (f'Centroid found in area {test_pt}, obj_name: {res.names[i].data[4:]}')
            print ('Grasping May have failed')

# %%
if len (objects)!=0 :
    for i in range(len(res.poses)):
        #tf_man.getTF("head_rgbd_sensor_rgb_frame")
        position = [res.poses[i].position.x ,res.poses[i].position.y,res.poses[i].position.z]
        print ('position,name',position,res.names[i].data[4:])
        ##########################################################

        object_point = PointStamped()
        object_point.header.frame_id = "head_rgbd_sensor_rgb_frame"
        object_point.point.x = position[0]
        object_point.point.y = position[1]
        object_point.point.z = position[2]
        position_map = tfBuffer.transform(object_point, "map", timeout=rospy.Duration(1))
        
        
        
        print ('position_map',position_map)
        tf_man.pub_static_tf(pos= [position_map.point.x,position_map.point.y,position_map.point.z], rot=[0,0,0,1], ref="map", point_name=res.names[i].data[4:] )
        new_row = {'x': position_map.point.x, 'y': position_map.point.y, 'z': position_map.point.z, 'obj_name': res.names[i].data[4:]}
        objs.loc[len(objs)] = new_row
        ###########################################################

# %%
head.to_tf('plum')

# %%
base_grasp_D('plum',timeout=30)

# %%
objs['x']

# %%
obj_pt=np.asarray((position_map.point.x,
position_map.point.y,
position_map.point.z))

if np.linalg.norm(pose_target-obj_pt)<0.05:print ('I say chale man')

# %%
pose_target,_=tf_man.getTF('plum')

# %%
objs['x']

# %%
np.linalg.norm(pose_target-obj_pt)

# %%
pose_target

# %%
obj_pt

# %%
av=arm.get_current_joint_values()
av
# Out:
# [0.6808629824410867,
#  -0.7439015280188852,
#  -1.570698345343694,
#  -1.5706966302849659,
#  -0.0003068917761841483,
#  0.0]

# %%
brazo.set_joint_values(av[:-1])

# %%
#### SET UP REGIONS

rospack = rospkg.RosPack()

# %%
file_path = rospack.get_path('config_files')+'/regions'         
regions={'shelves':np.load(file_path+'/shelf_sim.npy'),'pickup':np.load(file_path+'/pickup_sim.npy')}
#regions={'shelves':np.load(file_path+'/shelves_region.npy'),'pickup':np.load(file_path+'/pickup_region.npy')}
print('area box',regions,'###################################')
# Out:
# area box {'shelves': array([[7.7, 6.2],
#        [8.6, 5.9]]), 'pickup': array([[5.8, 6. ],
#        [7. , 4. ]])} ###################################

# %%
regions['pickup'][1,1]=-4.1

# %%
print('area box',regions['shelves'],'###################################')
# Out:
# area box [[ 9.5 -4.1]
#  [10.4 -4.8]] ###################################

# %%
#np.save(('/home/roboworks/catkin_extras/src/navigation_pumas/config_files/regions/shelves_region.npy'),regions['shelves'])

# %%
x,y=np.mean(regions['shelves'], axis=0)
z=0.4#self.mid_shelf_height=0.4 shelves heights must also be set on SCAN SHELF  state init sectoin.

tf_man.pub_static_tf(pos=[x,y,z],point_name='placing_area_test')
# Out:
# [ WARN] [1712785927.771201749]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 907.891000 according to authority /pose_integrator
# [ WARN] [1712785927.771253031]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 907.891000 according to authority /pose_integrator
# [ WARN] [1712785927.771294982]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 907.891000 according to authority /pose_integrator
# [ WARN] [1712785927.771334366]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 907.891000 according to authority /pose_integrator
# [ WARN] [1712785927.771374247]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 907.891000 according to authority /pose_integrator
# [ WARN] [1712785927.771413154]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 907.891000 according to authority /pose_integrator
# [ WARN] [1712785927.864035687]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 907.951000 according to authority /pose_integrator
# [ WARN] [1712785927.864092075]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 907.951000 according to authority /pose_integrator
# [ WARN] [1712785927.864129055]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 907.951000 according to authority /pose_integrator
# [ WARN] [1712785927.864163325]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 907.951000 according to authority /pose_integrator
# [ WARN] [1712785927.864200668]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 907.951000 according to authority /pose_integrator
# [ WARN] [1712785927.864234093]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 907.951000 according to authority /pose_integrator
# [ WARN] [1712785928.095803117]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 908.077000 according to authority /pose_integrator
# [ WARN] [1712785928.095852208]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 908.077000 according to authority /pose_integrator
# [ WARN] [1712785928.095890841]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 908.077000 according to authority /pose_integrator
# [ WARN] [1712785928.095933386]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 908.077000 according to authority /pose_integrator
# [ WARN] [1712785928.095963805]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 908.077000 according to authority /pose_integrator
# [ WARN] [1712785928.096000564]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 908.077000 according to authority /pose_integrator
# [ WARN] [1712785929.434206529]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 908.761000 according to authority /pose_integrator
# [ WARN] [1712785929.434254706]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 908.761000 according to authority /pose_integrator
# [ WARN] [1712785929.434292255]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 908.761000 according to authority /pose_integrator
# [ WARN] [1712785929.434326183]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 908.761000 according to authority /pose_integrator
# [ WARN] [1712785929.434351048]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 908.761000 according to authority /pose_integrator
# [ WARN] [1712785929.434380129]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 908.761000 according to authority /pose_integrator
# [ WARN] [1712785931.091438216]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 909.509000 according to authority /pose_integrator
# [ WARN] [1712785931.091488365]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 909.509000 according to authority /pose_integrator
# [ WARN] [1712785931.091517709]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 909.509000 according to authority /pose_integrator
# [ WARN] [1712785931.091549885]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 909.509000 according to authority /pose_integrator
# [ WARN] [1712785931.091588655]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 909.509000 according to authority /pose_integrator
# [ WARN] [1712785931.091621791]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 909.509000 according to authority /pose_integrator
# [ WARN] [1712785936.931506265]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 912.111000 according to authority /pose_integrator
# [ WARN] [1712785936.931578370]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 912.111000 according to authority /pose_integrator
# [ WARN] [1712785936.931624695]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 912.111000 according to authority /pose_integrator
# [ WARN] [1712785936.931681467]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 912.111000 according to authority /pose_integrator
# [ WARN] [1712785936.931716786]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 912.111000 according to authority /pose_integrator
# [ WARN] [1712785936.931764812]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 912.111000 according to authority /pose_integrator
# [ WARN] [1712785937.432969834]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 912.361000 according to authority /pose_integrator
# [ WARN] [1712785937.433020009]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 912.361000 according to authority /pose_integrator
# [ WARN] [1712785937.433060035]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 912.361000 according to authority /pose_integrator
# [ WARN] [1712785937.433100035]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 912.361000 according to authority /pose_integrator
# [ WARN] [1712785937.433142840]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 912.361000 according to authority /pose_integrator
# [ WARN] [1712785937.433171581]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 912.361000 according to authority /pose_integrator
# [ WARN] [1712785939.759787486]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 913.463000 according to authority /pose_integrator
# [ WARN] [1712785939.759838496]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 913.463000 according to authority /pose_integrator
# [ WARN] [1712785939.759876673]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 913.463000 according to authority /pose_integrator
# [ WARN] [1712785939.759910430]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 913.463000 according to authority /pose_integrator
# [ WARN] [1712785939.759946929]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 913.463000 according to authority /pose_integrator
# [ WARN] [1712785939.759979910]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 913.463000 according to authority /pose_integrator
# [ WARN] [1712785946.353468831]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 916.266000 according to authority /pose_integrator
# [ WARN] [1712785946.353520710]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 916.266000 according to authority /pose_integrator
# [ WARN] [1712785946.353564837]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 916.266000 according to authority /pose_integrator
# [ WARN] [1712785946.353591362]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 916.266000 according to authority /pose_integrator
# [ WARN] [1712785946.353615046]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 916.266000 according to authority /pose_integrator
# [ WARN] [1712785946.353638023]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 916.266000 according to authority /pose_integrator
# [ WARN] [1712785947.757852305]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 916.893000 according to authority /pose_integrator
# [ WARN] [1712785947.757911429]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 916.893000 according to authority /pose_integrator
# [ WARN] [1712785947.757945140]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 916.893000 according to authority /pose_integrator
# [ WARN] [1712785947.757970689]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 916.893000 according to authority /pose_integrator
# [ WARN] [1712785947.757992199]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 916.893000 according to authority /pose_integrator
# [ WARN] [1712785947.758012886]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 916.893000 according to authority /pose_integrator
# [ WARN] [1712785948.195332378]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 917.093000 according to authority /pose_integrator
# [ WARN] [1712785948.195380020]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 917.093000 according to authority /pose_integrator
# [ WARN] [1712785948.195416698]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 917.093000 according to authority /pose_integrator
# [ WARN] [1712785948.195447120]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 917.093000 according to authority /pose_integrator
# [ WARN] [1712785948.195481739]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 917.093000 according to authority /pose_integrator
# [ WARN] [1712785948.195518601]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 917.093000 according to authority /pose_integrator
# [ WARN] [1712785950.270281291]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 917.956000 according to authority /pose_integrator
# [ WARN] [1712785950.270351744]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 917.956000 according to authority /pose_integrator
# [ WARN] [1712785950.270391015]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 917.956000 according to authority /pose_integrator
# [ WARN] [1712785950.270426779]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 917.956000 according to authority /pose_integrator
# [ WARN] [1712785950.270462629]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 917.956000 according to authority /pose_integrator
# [ WARN] [1712785950.270498695]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 917.956000 according to authority /pose_integrator
# [ WARN] [1712785952.568256392]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 919.081000 according to authority /pose_integrator
# [ WARN] [1712785952.568302704]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 919.081000 according to authority /pose_integrator
# [ WARN] [1712785952.568330132]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 919.081000 according to authority /pose_integrator
# [ WARN] [1712785952.568362215]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 919.081000 according to authority /pose_integrator
# [ WARN] [1712785952.568392110]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 919.081000 according to authority /pose_integrator
# [ WARN] [1712785952.568417828]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 919.081000 according to authority /pose_integrator
# [ WARN] [1712785953.592202556]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 919.554000 according to authority /pose_integrator
# [ WARN] [1712785953.592263908]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 919.554000 according to authority /pose_integrator
# [ WARN] [1712785953.592299807]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 919.554000 according to authority /pose_integrator
# [ WARN] [1712785953.592324367]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 919.554000 according to authority /pose_integrator
# [ WARN] [1712785953.592347335]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 919.554000 according to authority /pose_integrator
# [ WARN] [1712785953.592378153]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 919.554000 according to authority /pose_integrator
# [ WARN] [1712785954.050611355]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 919
: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 933.874000 according to authority /pose_integrator
# [ WARN] [1712785984.884689108]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 933.874000 according to authority /pose_integrator
# [ WARN] [1712785984.884710727]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 933.874000 according to authority /pose_integrator
# [ WARN] [1712785984.884732406]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 933.874000 according to authority /pose_integrator
# [ WARN] [1712785984.884754871]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 933.874000 according to authority /pose_integrator
# [ WARN] [1712785985.936618673]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 934.388000 according to authority /pose_integrator
# [ WARN] [1712785985.936678106]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 934.388000 according to authority /pose_integrator
# [ WARN] [1712785985.936703667]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 934.388000 according to authority /pose_integrator
# [ WARN] [1712785985.936726841]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 934.388000 according to authority /pose_integrator
# [ WARN] [1712785985.936750135]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 934.388000 according to authority /pose_integrator
# [ WARN] [1712785985.936779283]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 934.388000 according to authority /pose_integrator
# [ WARN] [1712785988.661866643]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 935.694000 according to authority /pose_integrator
# [ WARN] [1712785988.661925723]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 935.694000 according to authority /pose_integrator
# [ WARN] [1712785988.661969819]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 935.694000 according to authority /pose_integrator
# [ WARN] [1712785988.662008543]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 935.694000 according to authority /pose_integrator
# [ WARN] [1712785988.662051938]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 935.694000 according to authority /pose_integrator
# [ WARN] [1712785988.662090729]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 935.694000 according to authority /pose_integrator
# [ WARN] [1712785988.848590470]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 935.782000 according to authority /pose_integrator
# [ WARN] [1712785988.848646681]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 935.782000 according to authority /pose_integrator
# [ WARN] [1712785988.848698029]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 935.782000 according to authority /pose_integrator
# [ WARN] [1712785988.848740064]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 935.782000 according to authority /pose_integrator
# [ WARN] [1712785988.848776855]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 935.782000 according to authority /pose_integrator
# [ WARN] [1712785988.848810962]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 935.782000 according to authority /pose_integrator
# [ WARN] [1712785990.126834271]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 936.322000 according to authority /pose_integrator
# [ WARN] [1712785990.126887636]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 936.322000 according to authority /pose_integrator
# [ WARN] [1712785990.126925150]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 936.322000 according to authority /pose_integrator
# [ WARN] [1712785990.126958905]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 936.322000 according to authority /pose_integrator
# [ WARN] [1712785990.126990852]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 936.322000 according to authority /pose_integrator
# [ WARN] [1712785990.127023868]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 936.322000 according to authority /pose_integrator
# [ WARN] [1712785992.341431976]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 937.345000 according to authority /pose_integrator
# [ WARN] [1712785992.341469964]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 937.345000 according to authority /pose_integrator
# [ WARN] [1712785992.341494845]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 937.345000 according to authority /pose_integrator
# [ WARN] [1712785992.341517934]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 937.345000 according to authority /pose_integrator
# [ WARN] [1712785992.341541900]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 937.345000 according to authority /pose_integrator
# [ WARN] [1712785992.341566234]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 937.345000 according to authority /pose_integrator
# [ WARN] [1712785995.836303822]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 939.087000 according to authority /pose_integrator
# [ WARN] [1712785995.836348248]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 939.087000 according to authority /pose_integrator
# [ WARN] [1712785995.836401973]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 939.087000 according to authority /pose_integrator
# [ WARN] [1712785995.836427455]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 939.087000 according to authority /pose_integrator
# [ WARN] [1712785995.836459962]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 939.087000 according to authority /pose_integrator
# [ WARN] [1712785995.836486319]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 939.087000 according to authority /pose_integrator
# [ WARN] [1712785997.931608779]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 940.021000 according to authority /pose_integrator
# [ WARN] [1712785997.931660364]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 940.021000 according to authority /pose_integrator
# [ WARN] [1712785997.931698057]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 940.021000 according to authority /pose_integrator
# [ WARN] [1712785997.931730018]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 940.021000 according to authority /pose_integrator
# [ WARN] [1712785997.931767274]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 940.021000 according to authority /pose_integrator
# [ WARN] [1712785997.931799561]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 940.021000 according to authority /pose_integrator
# [ WARN] [1712786001.910785910]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 941.863000 according to authority /pose_integrator
# [ WARN] [1712786001.910839179]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 941.863000 according to authority /pose_integrator
# [ WARN] [1712786001.910877525]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 941.863000 according to authority /pose_integrator
# [ WARN] [1712786001.910916610]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 941.863000 according to authority /pose_integrator
# [ WARN] [1712786001.910948701]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 941.863000 according to authority /pose_integrator
# [ WARN] [1712786001.910986858]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 941.863000 according to authority /pose_integrator
# [ WARN] [1712786002.572228992]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 942.166000 according to authority /pose_integrator
# [ WARN] [1712786002.572268671]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 942.166000 according to authority /pose_integrator
# [ WARN] [1712786002.572293251]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 942.166000 according to authority /pose_integrator
# [ WARN] [1712786002.572316369]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 942.166000 according to authority /pose_integrator
# [ WARN] [1712786002.572338757]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 942.166000 according to authority /pose_integrator
# [ WARN] [1712786002.572373519]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 942.166000 according to authority /pose_integrator
# [ WARN] [1712786010.478582927]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 945.664000 according to authority /pose_integrator
# [ WARN] [1712786010.478642494]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 945.664000 according to authority /pose_integrator
# [ WARN] [1712786010.478687019]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 945.664000 according to authority /pose_integrator
# [ WARN] [1712786010.478729355]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 945.664000 according to authority /pose_integrator
# [ WARN] [1712786010.478771008]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 945.664000 according to authority /pose_integrator
# [ WARN] [1712786010.478811476]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 945.664000 according to authority /pose_integrator
# [ WARN] [1712786013.610573184]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 946.950000 according to authority /pose_integrator
# [ WARN] [1712786013.610618948]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 946.950000 according to authority /pose_integrator
# [ WARN] [1712786013.610660733]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 946.950000 according to authority /pose_integrator
# [ WARN] [1712786013.610696003]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 946.950000 according to authority /pose_integrator
# [ WARN] [1712786013.610734277]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 946.950000 according to authority /pose_integrator
# [ WARN] [1712786013.610769489]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 946.950000 according to authority /pose_integrator
# [ WARN] [1712786018.911073539]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 949.277000 according to authority /pose_integrator
# [ WARN] [1712786018.911130652]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 949.277000 according to authority /pose_integrator
# [ WARN] [1712786018.911171189]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 949.277000 according to authority /pose_integrator
# [ WARN] [1712786018.911210305]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 949.277000 according to authority /pose_integrator
# [ WARN] [1712786018.911243188]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 949.277000 according to authority /pose_integrator
# [ WARN] [1712786018.911269153]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 949.277000 according to authority /pose_integrator
# [ WARN] [1712786021.787883145]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 950.455000 according to authority /pose_integrator
# [ WARN] [1712786021.787944150]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 950.455000 according to authority /pose_integrator
# [ WARN] [1712786021.787985499]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 950.455000 according to authority /pose_integrator
# [ WARN] [1712786021.788025614]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 950.455000 according to authority /pose_integrator
# [ WARN] [1712786021.788065535]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 950.455000 according to authority /pose_integrator
# [ WARN] [1712786021.788115431]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 950.455000 according to authority /pose_integrator

# %%
regions['shelves']
# Out:
# array([[7.7, 6.2],
#        [8.6, 5.9]])
