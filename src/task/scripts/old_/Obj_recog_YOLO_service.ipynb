# %%
from smach_utils2 import *
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %matplotlib inline
# Out:
# /home/roboworks/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
from object_classification.srv import *

# %%
classify_client = rospy.ServiceProxy('/classify', Classify)

# %%
image=rgbd.get_image()
plt.imshow(image)

# %%
hand_rgbd= HAND_RGB()

# %%
image=hand_rgbd.get_image()
plt.imshow(image)

# %%
res.

# %%
img_msg=bridge.cv2_to_imgmsg(image)
req=classify_client.request_class()
req.in_.image_msgs.append(img_msg)
res=      classify_client(req)
print (res.names )
# Out:
# [data: "050_medium_clamp", data: "040_large_marker", data: "057_racquetball", data: "073-e_lego_duplo", data: "020_pitcher_lid", data: "072-a_toy_airplane", data: "002_master_chef_can", data: "072-a_toy_airplane", data: "002_master_chef_can", data: "019-a_pitcher_base", data: "055_baseball", data: "070-a_colored_wood_blocks", data: "022_windex_bottle", data: "050_medium_clamp", data: "002_master_chef_can"]

# %%
debug_image=bridge.imgmsg_to_cv2(res.debug_image.image_msgs[0])

# %%
plt.imshow(debug_image)

# %%
tf_man.pub_static_tf(pos=[pose.position.x,pose.position.y,pose.position.z], rot =[0,0,0,1] , point_name='test', ref='head_rgbd_sensor_depth_frame')
tf_man.

# %%
for pose, point_name in zip(res.poses, res.names):
    print ([pose.position.x,pose.position.y,pose.position.z],[pose.orientation.x,pose.orientation.y,pose.orientation.z,pose.orientation.w],point_name.data ,'*******************************')

    tf_man.pub_static_tf(pos=[pose.position.x,pose.position.y,pose.position.z], rot =[pose.orientation.x,pose.orientation.y,pose.orientation.z,pose.orientation.w] , point_name=point_name.data, ref='map') #head_rgbd_sensor_rgb_frame')## which object to choose   #TODO
    tf_man.change_ref_frame_tf(point_name.data)

# %%
pose.position.x=cc[0]
pose.position.y=cc[1]
pose.position.z=cc[2]
pose.orientation.w=1
res.poses.append(pose)

# %%
l=res.pt_max.data

# %%
l

# %%
for i , data  in enumerate  (l):
    print(i,data)

# %%
omni_basei_basei_basei_base

# %%
res = omni_base.move_base(known_location='pickup')
