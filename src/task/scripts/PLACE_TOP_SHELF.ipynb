# %%
from smach_utils2 import *
import matplotlib.pyplot as plt
#arm = moveit_commander.MoveGroupCommander('arm')
# Out:
# /home/roboworks/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# [ WARN] [1713128894.026191977]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2445.312000 according to authority /pose_integrator
# [ WARN] [1713128894.411369676]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2445.522000 according to authority /pose_integrator
# [ WARN] [1713128894.927493181]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2445.743000 according to authority /pose_integrator
# [ WARN] [1713128895.484553232]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2446.012000 according to authority /pose_integrator
# [ WARN] [1713128896.401599632]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2446.128000 according to authority /pose_integrator
# [ WARN] [1713128896.878304650]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2446.579000 according to authority /pose_integrator
# [ WARN] [1713128896.878372927]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2446.579000 according to authority /pose_integrator
# [ WARN] [1713128896.878416285]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2446.579000 according to authority /pose_integrator
# [ WARN] [1713128896.878455142]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2446.579000 according to authority /pose_integrator
# [ WARN] [1713128896.878493280]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2446.579000 according to authority /pose_integrator
# [ WARN] [1713128896.878529599]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2446.579000 according to authority /pose_integrator
# [ WARN] [1713128897.663974928]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2446.881000 according to authority /pose_integrator
# [ WARN] [1713128897.664015845]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2446.881000 according to authority /pose_integrator
# [ WARN] [1713128897.664039903]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2446.881000 according to authority /pose_integrator
# [ WARN] [1713128897.664068924]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2446.881000 according to authority /pose_integrator
# [ WARN] [1713128897.664093584]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2446.881000 according to authority /pose_integrator
# [ WARN] [1713128897.664116002]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2446.881000 according to authority /pose_integrator

# %%
arm=moveit_commander.MoveGroupCommander('arm')

# %%
whole_body=moveit_commander.MoveGroupCommander('whole_body_weighted')

# %%
res = omni_base.move_base(known_location='place_shelf', time_out=200)
high_shelf_place=np.asarray([0.15050079265248406,
 -0.5861087653247212,
 0.0850017715788356,
 -0.9342371117035135,
 0.022035143687695324,
 0.0])
mid_shelf_place=np.asarray([0.2556342351169577,
 -1.6040815280188854,
 -0.008078345343693893,
 -0.05795663028496589,
 0.0019971082238159354,
 0.0])

low_shelf_place=np.asarray([0.04577467546491997,
 -2.262541528018885,
 0.00010865465630605087,
 0.701618369715034,
 -0.0003068917761841483,
 0.0]
)

# %%
head.set_joint_values([-0.5,-0.65])
arm.set_named_target('go')
arm.go()

# %%
rospy.sleep(0.6)
rospy.sleep(0.6)
image= cv2.cvtColor(rgbd.get_image(), cv2.COLOR_RGB2BGR)
img_msg  = bridge.cv2_to_imgmsg(image)
req      = classify_client.request_class()
req.in_.image_msgs.append(img_msg)
res      = classify_client(req)
debug_image=   cv2.cvtColor(bridge.imgmsg_to_cv2(res.debug_image.image_msgs[0]), cv2.COLOR_RGB2BGR)

# %%
plt.imshow(debug_image)

# %%
request= segmentation_server.request_class() 


#request.height.data=-1
request.height.data=0.68  #self.top_shelf_height=0.68 at init scan top shelf state

print ('#############Finding placing in plane####################',request.height.data)

res=placing_finder_server.call(request) 
#succ=seg_res_tf(res)
print (f'Placing Area at {res.poses.data}')
if len (res.poses.data)!=0:
    tf_man.pub_static_tf(pos=[res.poses.data[0], res.poses.data[1],res.poses.data[2]], rot =[0,0,0,1], point_name='placing_area')
#img=bridge.imgmsg_to_cv2(res.im_out.image_msgs[0])
#cv2.imshow('our of res'  , img)
#plt.imshow(img)
# Out:
# #############Finding placing in plane#################### 0.68
# [ WARN] [1713128898.823718531]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.384000 according to authority /pose_integrator
# [ WARN] [1713128898.823769816]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.384000 according to authority /pose_integrator
# [ WARN] [1713128898.823801546]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.384000 according to authority /pose_integrator
# [ WARN] [1713128898.823839434]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.384000 according to authority /pose_integrator
# [ WARN] [1713128898.823876912]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.384000 according to authority /pose_integrator
# [ WARN] [1713128898.823908267]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.384000 according to authority /pose_integrator
# [ WARN] [1713128899.729083605]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.716000 according to authority /pose_integrator
# [ WARN] [1713128899.729188198]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.716000 according to authority /pose_integrator
# [ WARN] [1713128899.732412188]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.716000 according to authority /pose_integrator
# [ WARN] [1713128899.732532935]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.716000 according to authority /pose_integrator
# [ WARN] [1713128899.732605412]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.716000 according to authority /pose_integrator
# [ WARN] [1713128899.732665726]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.716000 according to authority /pose_integrator
# [ WARN] [1713128899.963224187]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.846000 according to authority /pose_integrator
# [ WARN] [1713128899.963280639]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.846000 according to authority /pose_integrator
# [ WARN] [1713128899.963337468]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.846000 according to authority /pose_integrator
# [ WARN] [1713128899.963372560]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.846000 according to authority /pose_integrator
# [ WARN] [1713128899.963400001]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.846000 according to authority /pose_integrator
# [ WARN] [1713128899.963424604]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2447.846000 according to authority /pose_integrator
# Placing Area at ()
# [ WARN] [1713128900.401183771]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.089000 according to authority /pose_integrator
# [ WARN] [1713128900.401226116]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.089000 according to authority /pose_integrator
# [ WARN] [1713128900.401251177]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.089000 according to authority /pose_integrator
# [ WARN] [1713128900.401273464]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.089000 according to authority /pose_integrator
# [ WARN] [1713128900.401295825]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.089000 according to authority /pose_integrator
# [ WARN] [1713128900.401317999]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.089000 according to authority /pose_integrator
# [ WARN] [1713128900.719057260]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.239000 according to authority /pose_integrator
# [ WARN] [1713128900.719118588]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.239000 according to authority /pose_integrator
# [ WARN] [1713128900.719162497]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.239000 according to authority /pose_integrator
# [ WARN] [1713128900.719203973]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.239000 according to authority /pose_integrator
# [ WARN] [1713128900.719245563]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.239000 according to authority /pose_integrator
# [ WARN] [1713128900.719288239]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.239000 according to authority /pose_integrator
# [ WARN] [1713128900.860648894]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.315000 according to authority /pose_integrator
# [ WARN] [1713128900.860703031]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.315000 according to authority /pose_integrator
# [ WARN] [1713128900.860730693]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.315000 according to authority /pose_integrator
# [ WARN] [1713128900.860755891]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.315000 according to authority /pose_integrator
# [ WARN] [1713128900.860780527]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.315000 according to authority /pose_integrator
# [ WARN] [1713128900.860804835]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.315000 according to authority /pose_integrator
# [ WARN] [1713128901.225723201]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.477000 according to authority /pose_integrator
# [ WARN] [1713128901.225759374]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.477000 according to authority /pose_integrator
# [ WARN] [1713128901.225782864]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.477000 according to authority /pose_integrator
# [ WARN] [1713128901.225803878]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.477000 according to authority /pose_integrator
# [ WARN] [1713128901.225828183]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448.477000 according to authority /pose_integrator
# [ WARN] [1713128901.225850337]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2448
: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2592.334000 according to authority /pose_integrator
# [ WARN] [1713129213.796832085]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2592.334000 according to authority /pose_integrator
# [ WARN] [1713129213.796866756]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2592.334000 according to authority /pose_integrator
# [ WARN] [1713129213.796899676]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2592.334000 according to authority /pose_integrator
# [ WARN] [1713129213.796932634]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2592.334000 according to authority /pose_integrator
# [ WARN] [1713129214.075232278]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2592.437000 according to authority /pose_integrator
# [ WARN] [1713129214.075440303]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2592.437000 according to authority /pose_integrator
# [ WARN] [1713129214.075482998]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2592.437000 according to authority /pose_integrator
# [ WARN] [1713129214.075520039]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2592.437000 according to authority /pose_integrator
# [ WARN] [1713129214.075553680]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2592.437000 according to authority /pose_integrator
# [ WARN] [1713129214.075589365]: TF_REPEATED_DATA ignoring data with redundant timestamp for frame odom at time 2592.437000 according to authority /pose_integrator
# shutdown request: [/smach] Reason: new node registered with same name

# %%
res = omni_base.move_base(known_location='place_shelf', time_out=12)
head.set_joint_values([0.0,-0.35])

# %%
base_grasp_D(tf_name='placing_area',d_x=0.76, d_y=0.0,timeout=30)
arm.go (mid_shelf_place)
base_grasp_D(tf_name='placing_area',d_x=0.6, d_y=0.0,timeout=30)
gripper.open()

# %%
arm.go (mid_shelf_place)

# %%
base_grasp_D(tf_name='placing_area',d_x=0.6, d_y=0.0,timeout=30)
gripper.open()

# %%
for i in range(len(res.poses)):
    tf_man.getTF("head_rgbd_sensor_rgb_frame")
    tf_man.pub_static_tf(pos=[res.poses[i].position.x ,res.poses[i].position.y,res.poses[i].position.z], rot=[0,0,0,1],ref="head_rgbd_sensor_rgb_frame",point_name=res.names[i].data[4:] )   
    rospy.sleep(0.3)
    tf_man.change_ref_frame_tf(res.names[i].data[4:])

# %%
omni_base.move_d_to(target_distance=0.78,target_link='apple')

# %%
target_object='apple'
trans,_=tf_man.getTF(target_object,ref_frame="base_link")
trans

# %%
target_object='apple'
_,rot= tf_man.getTF("base_link",ref_frame='map')

original_rot=tf.transformations.euler_from_quaternion(rot)[2]
trans,_=tf_man.getTF(target_object,ref_frame="base_link")


trans , original_rot

# %%
_,rot= tf_man.getTF("base_link",ref_frame='map')
original_rot=tf.transformations.euler_from_quaternion(rot)[2]
target_object='apple'


succ = False
            
while not succ:
    
    _,rot= tf_man.getTF("base_link",ref_frame='map')
    trans,_=tf_man.getTF(target_object,ref_frame="base_link")

    trans
    eX, eY, eZ = trans
    
    eX+= -0.4
    eY+= -.06
    
    eT= tf.transformations.euler_from_quaternion(rot)[2] - original_rot #Original 
    print (eT)
    if eT > np.pi: eT=-2*np.pi+eT
    if eT < -np.pi: eT= 2*np.pi+eT
    rospy.loginfo("error: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(eX, eY , eT,target_object))
    X, Y, Z = trans
    rospy.loginfo("Pose: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(X, Y , eT,target_object))
    
    if abs(eX) <=0.05 :
        print ('here')
        eX = 0
    if abs(eY) <=0.05  :
        eY = 0
    if abs(eT   ) < 0.1:
        eT = 0
    succ =  eX == 0 and eY == 0 and eT==0

    
    omni_base.tiny_move( velX=0.2*+eX,velY=0.3*eY, velT=-eT,std_time=0.2, MAX_VEL=0.3)

# %%
res.names

# %%
hand_cam= HAND_RGB()

# %%
#clear_octo_client()

pickup_pose=[0.65,-1.2,0.0,-1.9, 0.0, 0.0]
succ= arm.go(pickup_pose)
gripper.open()

# %%
image= cv2.cvtColor(hand_cam.get_image(), cv2.COLOR_RGB2BGR)
img_msg  = bridge.cv2_to_imgmsg(image)
req      = classify_client.request_class()
req.in_.image_msgs.append(img_msg)
res      = classify_client(req)
debug_image=   cv2.cvtColor(bridge.imgmsg_to_cv2(res.debug_image.image_msgs[0]), cv2.COLOR_RGB2BGR)
for i in range(len(res.names)):
    if res.names[i].data== '013_apple' or res.names[i].data== '017_orange':
        bbM=res.pt_min.data[2*i:2*i+2]
        bbm=res.pt_max.data[2*i:2*i+2]
        bbx=[bbM,bbm]
print(bbx)
plt.imshow(debug_image)

# %% [markdown]
# # [(297, 191), (231, 226)]  at pkcp pose #Real Tak
# ### [(323, 266), (280, 215)]  at pkcp pose #Gazebo

# %%
eX,eY= 0.3,0.3 

while abs(eX) > 0.05 or abs(eY) > 0.05:
    image= cv2.cvtColor(hand_cam.get_image(), cv2.COLOR_RGB2BGR)
    img_msg  = bridge.cv2_to_imgmsg(image)
    req      = classify_client.request_class()
    req.in_.image_msgs.append(img_msg)
    res      = classify_client(req)


    for i in range(len(res.names)):
        if res.names[i].data== '013_apple' or res.names[i].data== '017_orange':
            bbM=res.pt_min.data[2*i:2*i+2]
            bbm=res.pt_max.data[2*i:2*i+2]
            bbx=[bbM,bbm]
    print(bbx)
    eY=(bbx[1][1]-215)/215    #experience value
    #print(f'error relative to gripper cam {eY}')


    #eX=(bbx[0][0]-323)/323
    eY=(bbx[1][1]-239)/239
    eX=(bbx[0][0]-312)/312
    #eY=(bbx[1][1]-215)/215    #experience value

    print(f'error relative to gripper cam ex={eX} ey={eY}')
    omni_base.tiny_move(velX=0.5*eX, velY=0.5*-eY, MAX_VEL=0.05) 
print(f'error relative to gripper cam ex={eX} ey={eY}:::::: Error within tolerance')

# %%
bbx

# %%
eY=(bbx[1][1]-239)/239
eX=(bbx[0][0]-312)/312
print(f'error relative to gripper cam ex={eX} ey={eY}')

# %%
#omni_base.tiny_move(velX=0.5*eX, velY=0.5*-eY, MAX_VEL=0.05)

# %%
clear_octo_client()

av=arm.get_current_joint_values()
print (av,'av')
av[0]+= -0.17###LAB
#av[0]+= -0.35###GAZ
succ=arm.go(av)
rospy.sleep(0.5)
gripper.close(force=0.06)

# %%
av=arm.get_current_joint_values()
print (av,'av')
av[0]+= 0.15
succ=arm.go(av)
omni_base.tiny_move(velX=-0.3, std_time=4.0)
arm.set_named_target('go')
arm.go()
#tf_man.pub_static_tf(point_name='apple')

# %%
plt.imshow(hand_cam.get_image())

# %%
image= cv2.cvtColor(hand_cam.get_image(), cv2.COLOR_RGB2BGR)
img_msg  = bridge.cv2_to_imgmsg(image)
req      = classify_client.request_class()
req.in_.image_msgs.append(img_msg)
res      = classify_client(req)
debug_image=   cv2.cvtColor(bridge.imgmsg_to_cv2(res.debug_image.image_msgs[0]), cv2.COLOR_RGB2BGR)
plt.imshow(debug_image)

# %%
gripper.open()

# %%
gripper.close(force=0.06)

# %%
for i in range(len(res.poses)):
    tf_man.getTF("head_rgbd_sensor_rgb_frame")
    position = [res.poses[i].position.x ,res.poses[i].position.y,res.poses[i].position.z]
    tf_man.pub_static_tf(pos= position, rot=[0,0,0,1], ref="head_rgbd_sensor_rgb_frame", point_name=res.names[i].data[4:] )   
    rospy.sleep(0.3)
    tf_man.change_ref_frame_tf(res.names[i].data[4:])

# %%
def detect_object_yolo(object_name,res):
    # find object_name in the response message from object_classification service (Yolo)
    objs=[]
    for i,name in enumerate(res.names):
        objs.append(name.data[4:])
        if name.data[4:]==object_name:return res.poses[i]
    if object_name=='all':
        
        return objs
    return []

# %%
#img_msg  = bridge.cv2_to_imgmsg(rgbd.get_image())  #REAL
img_msg  = bridge.cv2_to_imgmsg(cv2.cvtColor(rgbd.get_image(), cv2.COLOR_RGB2BGR ))#GAZEB
req      = classify_client.request_class()
req.in_.image_msgs.append(img_msg)
res      = classify_client(req)
objects=detect_object_yolo('all',res)   
if len (objects)!=0:
    for i in range(len(res.poses)):
        tf_man.getTF("head_rgbd_sensor_rgb_frame")
        position = [res.poses[i].position.x ,res.poses[i].position.y,res.poses[i].position.z]
        tf_man.pub_static_tf(pos= position, rot=[0,0,0,1], ref="head_rgbd_sensor_rgb_frame", point_name=res.names[i].data[4:] )   
        rospy.sleep(0.3)
        tf_man.change_ref_frame_tf(res.names[i].data[4:])
        rospy.sleep(0.3)
        pose , _=tf_man.getTF(res.names[i].data[4:])
        new_row = {'x': pose[0], 'y': pose[1], 'z': pose[2], 'obj_name': res.names[i].data[4:]}
        objs.loc[len(objs)] = new_row
objs

# %%
objs[['x','y','z']].values

# %%
#get closest object
rob_pos,_=tf_man.getTF('base_link')
np.argmin(np.linalg.norm(rob_pos-objs[['x','y','z']].values  , axis=1))
objs.iloc[np.argmin(np.linalg.norm(rob_pos-objs[['x','y','z']].values  , axis=1))]['obj_name']

# %%
objs[objs['obj_name']==objs.obj_name.values[0]].x.values[0]

# %% [markdown]
# # PLANE 1
# #### 7.883384	5.948245	0.701945,
# #### 8.214565	5.962619	0.700034,
# #### 8.213697	6.107727	0.709487,
# ####  7.893623	6.082935	0.693285

# %% [markdown]
# # PLANE 2
# #### 7.88076	6.086619	0.416096,
# #### 8.214128	5.9663	0.416672

# %% [markdown]
# # Plane 3
# #### 8.20238	5.963262	0.117541

# %%
head.set_named_target('neutral')

av=arm.get_current_joint_values()
av[0]=0.5
av[1]=-0.5
arm.go(av)
head.set_joint_values([-np.pi/2 , -0.5])

# %%
head.set_joint_values([-np.pi/2 , -0.5])

# %%
av=arm.get_current_joint_values()
av[0]=0.05

arm.go(av)

# %%
head.set_joint_values([-np.pi/2 , -0.8])

av=arm.get_current_joint_values()
av[0]=0.0
av[1]=-0.5
arm.go(av)

# %%
import pandas as pd

# %%
import pandas as pd
objs = pd.read_csv ('/home/roboworks/Documents/objs.csv')
objs=objs.drop(columns='Unnamed: 0')

# %%
objs=objs[objs['obj_name'] != 'bowl']

# %%
objs

# %%
objs[objs['obj_name'] != 'bowl']

# %%
objs

# %%
from sklearn.cluster import KMeans
shelf_objs=objs[objs['shelves']==True ]
sh_o_btm=shelf_objs[shelf_objs['z']<0.2]

# %%
'other' in sh_o_top['category'].values

# %%
shelf_objs=objs[objs['shelves']==True ]

sh_o_btm=shelf_objs[shelf_objs['z']<0.2]
sh_o_mdl=shelf_objs[(shelf_objs['z']>0.2 )& (shelf_objs['z']<0.5) ]
sh_o_top=shelf_objs[(shelf_objs['z']>0.5 )& (shelf_objs['z']<1.5) ]
sh_o_btm['category'].value_counts(),sh_o_mdl['category'].value_counts() 

a= sh_o_btm['category'].value_counts()
if 'other' in sh_o_btm['category'].values:a.drop('other', inplace=True)
print(f'btm shelf category {a.index[a.argmax()]}')

a= sh_o_mdl['category'].value_counts()
if 'other' in sh_o_mdl['category'].values:a.drop('other', inplace=True)
print(f'middle shelf category {a.index[a.argmax()]}')


a= sh_o_top['category'].value_counts()
if 'other' in sh_o_top['category'].values:a.drop('other', inplace=True)
print(f'top shelf category {a.index[a.argmax()]}')

# %%
a

# %%
kitchen =['bowl','spatula','spoon', 'bowl']
tools=['extra_large_clamp','large_clamp','small_clamp','medium_clamp','adjustable_wrench',
'flat_screwdriver','phillips_screwdriver','wood_block']
balls= ['softball','tennis_ball']
fruits= ['apple','banana', 'lemon','pear']
food =['chips_can'
,'mustard_bottle'
,'potted_meat_can'
,'tomato_soup_can'
,'tuna_fish_can']

def categorize_objs(name):
    if name in kitchen: return 'kitchen'
    elif name in tools: return 'tools'
    elif name in balls: return 'balls'
    elif name in fruits: return 'fruits'
    elif name in food: return 'food'
    return 'other'
cats=[]
for name in objs['obj_name']:
    cats.append(categorize_objs(name))
objs['category'] = cats

# %%
def categorize_objs(name):
    if name in kitchen: return 'kitchen'
    elif name in tools: return 'tools'
    elif name in balls: return 'balls'
    elif name in fruits: return 'fruits'
    elif name in food: return 'food'
    return 'other'

# %%
cats=[]
for name in objs['obj_name']:
    cats.append(categorize_objs(name))
objs['category'] = cats

# %%
objs

# %%
import numpy as np
regions={'shelves':np.load('/home/roboworks/Documents/shelf_sim.npy'),'pickup':np.load('/home/roboworks/Documents/pickup_sim.npy')}
def is_inside(x,y):return ((area_box[:,1].max() > y) and (area_box[:,1].min() < y)) and ((area_box[:,0].max() > x) and (area_box[0,0].min() < x)) 
for name in regions:
    in_region=[]
    area_box=regions[name]
    print (area_box,name)
    for index, row in objs[['x','y','z']].iterrows():
        in_region.append(is_inside(row.x, row.y))
        print (row.x, row.y,is_inside(row.x, row.y))
    objs[name]=pd.Series(in_region)
objs

# %%
(area_box[:,1].max() > row.y),(area_box[:,1].min() < row.y),((area_box[:,0].max() > row.x) , (area_box[0,0].min() < row.x))

# %%
def is_inside(x,y):return ((area_box[:,1].max() > y) and (area_box[:,1].min() < y)) and ((area_box[:,0].max() > x) and (area_box[0,0].min() < x))

# %%
pickup_region=np.zeros((2,2))
#np.save('/home/roboworks/Documents/pickup_region.npy', pickup_region)

# %%
ab[0,0],ab[0,1]=6,6
ab[1,0],ab[1,1]=7,4.0

# %%
import numpy as np

#ab=np.load('/home/roboworks/Documents/pickup_region.npy')
ab= np.load('/home/roboworks/Documents/pickup_sim.npy')

# %%
ab[0,0]=5.8
ab

# %%
np.save('/home/roboworks/Documents/pickup_region.npy',ab)

# %%
#np.save('/home/roboworks/Documents/shelf_sim.npy',ab)
np.save('/home/roboworks/Documents/pickup_sim.npy',ab)

# %%
objs[objs['pickup']==True][['x','y','z']].values

# %%
rob_pos,_=tf_man.getTF('base_link')
ix=np.argmin(np.linalg.norm(rob_pos-objs[objs['pickup']==True][['x','y','z']].values  , axis=1))
ix

# %%
rob_pos,_=tf_man.getTF('base_link')
ix=np.argmin(np.linalg.norm(rob_pos-objs[objs['pickup']==True][['x','y','z']].values  , axis=1))
objs[objs['pickup']==True][['obj_name','category']].iloc[ix]

# %%
ix=np.argmin(np.linalg.norm(rob_pos-objs[objs['pickup']==True][['x','y','z']].values  , axis=1))

# %%
pose=np.asarray((8.212561, 6.028789, 0.12))
pose

# %%
tf_man.pub_static_tf(pos=pose,point_name='PLACING')

# %%
#pose=np.asarray((8.212561, 6.028789, 0.12))
pose=np.asarray((8.062455, 6.0622816, 0.6610926))
tf_man.pub_static_tf(pos=pose,point_name='PLACING')

# %%
arm['arm_lift_joint']=0.0

# %%
omni_base.move_base(known_location='shelf')

# %%
omni_base.tiny_move(velT=-0.7,std_time=1)

# %%
av=arm.get_current_joint_values()
high_shelf_place=av
high_shelf_place

# %%
place_high_shelf=np.asarray([0.15050079265248406,
 -0.5861087653247212,
 0.0850017715788356,
 -0.9342371117035135,
 0.022035143687695324,
 0.0])

# %%
arm.go(place_high_shelf)

# %% [markdown]
# av=arm.get_current_joint_values()

# %%
av=arm.get_current_joint_values()
high_shelf_place=av

# %%
arm.go(high_shelf_place)

# %%
av=arm.get_current_joint_values()
mid_shelf_place=av
mid_shelf_place

# %%
av=arm.get_current_joint_values()
low_shelf_place=av
low_shelf_place

# %%
high_shelf_place,low_shelf_place,mid_shelf_place

# %%
high_shelf_place=np.asarray([0.4337121304669095,
 -1.3139266720690426,
 0.08621383272112926,
 -0.4260850221072081,
 0.02285051353933021,
 0.0])

# %%
low_shelf_place=np.asarray([-5.465250513158978e-07,
 -1.8875162206087301,
 0.08646571240675005,
 0.3040738848075222,
 0.022992974203400962,
 0.0]
)

# %%
high_shelf_place=np.asarray([0.15050079265248406,
 -0.5861087653247212,
 0.0850017715788356,
 -0.9342371117035135,
 0.022035143687695324,
 0.0])
mid_shelf_place=np.asarray([0.2556342351169577,
 -1.6040815280188854,
 -0.008078345343693893,
 -0.05795663028496589,
 0.0019971082238159354,
 0.0])

low_shelf_place=np.asarray([0.04577467546491997,
 -2.262541528018885,
 0.00010865465630605087,
 0.701618369715034,
 -0.0003068917761841483,
 0.0]
)

# %%
tf_man.getTF('placing_area_top_shelf1')

# %%
request= segmentation_server.request_class() 
#r = cv2.getTrackbarPos('Plane height (cms)', 'class rgbd')
#request.height.data=0.9
print ('#############Finding placing in plane####################',request.height.data)
request.height.data=-1
#head.set_joint_values([ 0.1, -0.5])
res=placing_finder_server.call(request)
#succ=seg_res_tf(res)
print (f'Placing Area at {res.poses.data}')
tf_man.pub_static_tf(pos=[res.poses.data[0], res.poses.data[1],res.poses.data[2]], rot =[0,0,0,1], point_name='placing_area')
img=bridge.imgmsg_to_cv2(res.im_out.image_msgs[0])
#cv2.imshow('our of res'  , img)
plt.imshow(img)

# %%
tf_man.getTF('placing_area')

# %%
head.set_named_target('neutral')

# %%
arm.set_named_target('go')
arm.go()

# %%
res = omni_base.move_base(known_location='place_shelf', time_out=10)

# %%
high_shelf_place=[0.65,         -1.139,         0.08621,        -0.4260,        0.02285,         0.0]#REAL
high_shelf_place=[0.4337,         -1.3139,         0.08621,        -0.4260,        0.02285,         0.0] #GAZ

# %%
arm.set_joint_value_target(high_shelf_place)
arm.go()

# %%
def base_grasp_D(tf_name,d_x=0.66,d_y=-0.1,timeout=1.0):
    timeout = rospy.Time.now().to_sec() + timeout
    rob_pos,rot=tf_man.getTF('base_link')    
    original_rot=tf.transformations.euler_from_quaternion(rot)[2]
    succ = False 
    target_object= tf_name        
    while (timeout >= rospy.Time.now().to_sec()) and not succ:            
        _,rot= tf_man.getTF("base_link",ref_frame='map')
        trans,_=tf_man.getTF(target_object,ref_frame="base_link")
        #trans
        eX, eY, eZ = trans
        eX+= -d_x  #x offest
        eY+= -d_y #y Offset
        eT= tf.transformations.euler_from_quaternion(rot)[2] - original_rot #Original 
        print (eT)
        if eT > np.pi: eT=-2*np.pi+eT
        if eT < -np.pi: eT= 2*np.pi+eT
        rospy.loginfo("error: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(eX, eY , eT,target_object))
        X, Y, Z = trans
        rospy.loginfo("Pose: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(X, Y , eT,target_object))
        if abs(eX) <=0.05 :
            print ('here')
            eX = 0
        if abs(eY) <=0.05  :
            eY = 0
        if abs(eT   ) < 0.1:
            eT = 0
        succ =  eX == 0 and eY == 0 and eT==0            
        omni_base.tiny_move( velX=0.2*+eX,velY=0.3*eY, velT=-eT,std_time=0.2, MAX_VEL=0.3)

# %%
tf_man.getTF('placing_area')

# %%
base_grasp_D(tf_name='placing_area')

# %%
base_grasp_D(tf_name='placing_area',d_x=0.76, d_y=0.0,timeout=30)

# %%
gripper.open()

# %%
target_object='placing_area'
_,rot= tf_man.getTF("base_link",ref_frame='map')
trans,_=tf_man.getTF(target_object,ref_frame="base_link")

 
eX, eY, eZ = trans
eT= tf.transformations.euler_from_quaternion(rot)[2] - original_rot #Original 
print (eT)
if eT > np.pi: eT=-2*np.pi+eT
if eT < -np.pi: eT= 2*np.pi+eT
rospy.loginfo("error: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(eX, eY , eT,target_object))
X, Y, Z = trans
rospy.loginfo("Pose: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(X, Y , eT,target_object))

# %%
omni_base.tiny_move( velX=0.1*+eX,velY=0.1*eY, velT=-eT,std_time=0.2, MAX_VEL=0.3)

# %%
d_x=0.58
d_y= 0.1
_,rot= tf_man.getTF("base_link",ref_frame='map')
trans,_=tf_man.getTF(target_object,ref_frame="base_link")
#trans
eX, eY, eZ = trans
eX+= -d_x  #x offest
eY+= -d_y #y Offset
eT= tf.transformations.euler_from_quaternion(rot)[2] - original_rot #Original 
print (eT)
if eT > np.pi: eT=-2*np.pi+eT
if eT < -np.pi: eT= 2*np.pi+eT
rospy.loginfo("error: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(eX, eY , eT,target_object))
X, Y, Z = trans
rospy.loginfo("Pose: {:.2f}, {:.2f}, angle {:.2f}, target obj frame {}".format(X, Y , eT,target_object))
if abs(eX) <=0.05 :
    print ('here')
    eX = 0
if abs(eY) <=0.05  :
    eY = 0
if abs(eT   ) < 0.1:
    eT = 0
succ =  eX == 0 and eY == 0 and eT==0      
succ
#omni_base.tiny_move( velX=0.2*+eX,velY=0.3*eY, velT=-eT,std_time=0.2, MAX_VEL=0.3)

# %%
omni_base.tiny_move( velX=0.1*+eX,velY=0.1*eY, velT=-eT,std_time=0.2, MAX_VEL=0.3)

# %%
arm.get_current_pose()

# %%
av=arm.get_current_joint_values()
av[0]+=-0.1
arm.go(av)

# %%
arm.set_named_target('go')
arm.go()

# %%
omni_base.move_base('place_shelf')

# %%
whole_body.allow_replanning(True)
whole_body.set_num_planning_attempts(10)
whole_body.set_planning_time(10.0)
whole_body.set_workspace([-2.0, -2.0, 0.0, 2.0, 2.0, 2.0])

# %%
object_point = PointStamped()
object_point

# %%
target_position=[1.0,1.0,1.0]
object_point = PointStamped()
object_point.header.frame_id = "base_link"
object_point.point.x = target_position[0]
object_point.point.y = target_position[1]
object_point.point.z = target_position[2]
#transformar la posicion del objeto al marco de referencia de la base del robot

try:
    transformed_object_point = tfBuffer.transform(object_point, "base_link", timeout=rospy.Duration(1))
    transformed_base = self.tfBuffer.lookup_transform("odom", "base_link", rospy.Time(0), timeout=rospy.Duration(1))
except :
    rospy.WARN("Error al transformar la posicion del objeto al marco de referencia")

# %%
tfBuffer.transform(object_point,'base_link',timeout=rospy.Duration(3))

# %%
whole_body.set_start_state_to_current_state()
whole_body.set_position_target(position_goal)
succ = whole_body.go(wait= True)
rospy.sleep(0.5)
whole_body.stop()

# %%
tfBuffer = tf2_ros.Buffer()

# %%
omni_base.move_base(known_location='pickup', time_out=200)

# %%
head.set_joint_values([ 0.0, -0.5])

# %%
img_msg  = bridge.cv2_to_imgmsg( cv2.cvtColor(rgbd.get_image(), cv2.COLOR_RGB2BGR))### GAZEBO BGR!?!??!
req      = classify_client.request_class()
req.in_.image_msgs.append(img_msg)
res      = classify_client(req)
objects=detect_object_yolo('all',res)

# %%
rospack = rospkg.RosPack()
file_path = rospack.get_path('config_files') 
objs = pd.read_csv (file_path+'/objects.csv')
objs=objs.drop(columns='Unnamed: 0')
print (objs)

# %%
def check_if_grasped(pose_target,test_pt,tolerance=0.05):    
    return np.linalg.norm(pose_target-obj_pt)<tolerance

# %%
np.linalg.norm(pose_target-obj_pt)

# %%
test_pt=objs[objs['obj_name']=='orange'][['x','y','z']].values
check_if_grasped(pose_target,test_pt)

# %%
def check_if_grasped(pose_target,test_pt,tolerance=0.05):return np.linalg.norm(pose_target-test_pt)<tolerance


##############################
pose_target,_=tf_man.getTF('plum')
#########################

if len (objects)!=0 :
    for i in range(len(res.poses)):
        
        position = [res.poses[i].position.x ,res.poses[i].position.y,res.poses[i].position.z]
        
        object_point = PointStamped()
        object_point.header.frame_id = "head_rgbd_sensor_rgb_frame"
        object_point.point.x = position[0]
        object_point.point.y = position[1]
        object_point.point.z = position[2]
        position_map = tfBuffer.transform(object_point, "map", timeout=rospy.Duration(1))
        
        tf_man.pub_static_tf(pos= [position_map.point.x,position_map.point.y,position_map.point.z], rot=[0,0,0,1], ref="map", point_name=res.names[i].data[4:] )
        test_pt=np.asarray((position_map.point.x,position_map.point.y,position_map.point.z))
        print (np.linalg.norm(pose_target-test_pt))
        if check_if_grasped(pose_target,test_pt):
            print (f'Centroid found in area {test_pt}, obj_name: {res.names[i].data[4:]}')
            print ('Grasping May have failed')

# %%
if len (objects)!=0 :
    for i in range(len(res.poses)):
        #tf_man.getTF("head_rgbd_sensor_rgb_frame")
        position = [res.poses[i].position.x ,res.poses[i].position.y,res.poses[i].position.z]
        print ('position,name',position,res.names[i].data[4:])
        ##########################################################

        object_point = PointStamped()
        object_point.header.frame_id = "head_rgbd_sensor_rgb_frame"
        object_point.point.x = position[0]
        object_point.point.y = position[1]
        object_point.point.z = position[2]
        position_map = tfBuffer.transform(object_point, "map", timeout=rospy.Duration(1))
        
        
        
        print ('position_map',position_map)
        tf_man.pub_static_tf(pos= [position_map.point.x,position_map.point.y,position_map.point.z], rot=[0,0,0,1], ref="map", point_name=res.names[i].data[4:] )
        new_row = {'x': position_map.point.x, 'y': position_map.point.y, 'z': position_map.point.z, 'obj_name': res.names[i].data[4:]}
        objs.loc[len(objs)] = new_row
        ###########################################################

# %%
head.to_tf('plum')

# %%
base_grasp_D('plum',timeout=30)

# %%
objs['x']

# %%
obj_pt=np.asarray((position_map.point.x,
position_map.point.y,
position_map.point.z))

if np.linalg.norm(pose_target-obj_pt)<0.05:print ('I say chale man')

# %%
pose_target,_=tf_man.getTF('plum')

# %%
objs['x']

# %%
np.linalg.norm(pose_target-obj_pt)

# %%
pose_target

# %%
obj_pt

# %%
av=arm.get_current_joint_values()
av
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 av=arm.get_current_joint_values()
#       2 av
#
# NameError: name 'arm' is not defined

# %%
brazo.set_joint_values(av[:-1])
